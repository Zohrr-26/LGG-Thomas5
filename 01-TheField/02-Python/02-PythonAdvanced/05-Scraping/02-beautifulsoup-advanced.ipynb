# %% [markdown]
# ### Targeted information retrieval

# %% [markdown]
# We have seen how to parse a webpage, which retrieves the information without distinction.
#
# But, in general, the purpose of scraping is to automate the collection of targeted information on the web.

# %%
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# Let's say I want to scrape the description of the latest movies released in theaters.
#
# So we'll go to the Allociné website and try to find the tags that will give me links to the specific pages of these movies to get their summaries.

# %% [markdown]
# #### Recovery of the url of the pages of films newly released in the theaters

# %%
url = "http://www.allocine.fr/"
r = requests.get(url)
print(url, r.status_code)
soup = BeautifulSoup(r.content, "lxml")

#---------------------------- only the body from the html page
soup = soup.find("body")
print(soup) ## write "soup" also print the content
# Out:
# http://www.allocine.fr/ 200
# <body class="allocine allocine__homepage logged-out" data-migration="incomplete" id="allocine__homepage">
# <div class="sub-body">
# <div class="js-interstitial ad-interstitial ad-item" id="dfp-interstitial"></div>
# <header class="header-main" id="header-main" role="banner">
# <div class="header-main-center">
# <div class="header-main-top">
# <div aria-label="Bouton Menu mobile" class="header-main-btn-mobile icon icon-hamburger" id="header-main-mobile-btn-menu"></div>
# <div class="header-main-logo-holder">
# <span class="ACrLw=ACr= header-main-logo">
# <img alt="allocine" class="header-main-logo-img" height="37" src="https://assets.allocine.fr/skin/img/allocine/logo-main.ab1b33da.svg" width="162"/>
# <span class="header-main-logo-name">AlloCiné</span>
# </span>
# </div>
# <form action="/rechercher/" aria-label="formulaire de recherche principal du site" class="header-main-search" id="search-header" method="get" role="form">
# <fieldset class="header-main-search-fieldset" id="search-engine">
# <div class="header-search-form-container"><input class="header-search-input" id="header-search-input" name="site_search[q]" placeholder="Rechercher un film, une série, une star..." type="text"/><button aria-label="Envoyer" class="header-search-submit icon icon-search" title="Rechercher" type="submit"></button></div> </fieldset>
# <p class="header-search-extralinks">
#                             Ex. :
#                             <a href="/tag-6035/films/">Meilleurs films d'animation Disney</a>, <a href="/tag-1141/films/">Meilleurs films Pixar</a> </p>
# <div class="header-main-search-mobile-layer" id="header-main-search-mobile-layer"></div>
# </form>
# <div class="header-ads-zone">
# <div class="js-headerlink ad-headerlink ad-item" id="dfp-headerlink"></div>
# </div>
# <div aria-label="Bouton Rechercher" class="header-main-btn-mobile icon icon-search" id="header-main-mobile-btn-search"></div>
# <div class="header-main-btn-mobile header-main-mobile-btn-userspace" id="header-main-mobile-btn-userspace">
# <span aria-label="Bouton Mon compte" class="icon icon-profil"></span>
# <img alt="" class="avatar js-myaccount-avatar" src="..."/>
# </div>
# </div>
# <div class="header-main-bottom">
# <nav aria-label="Menu principal du site" class="header-main-nav" id="header-main-nav" role="navigation"><ul class="header-nav-holder"><li class="header-nav-item"><span class="ACrL25ACrld3Mv header-nav-link" title="News">
#             News
#         </span></li><li class="header-nav-item"><a class="header-nav-link" href="/film/" title="Cinéma">
#             Cinéma
#         </a></li><li class="header-nav-item"><a class="header-nav-link" href="/series/" title="Séries">
#             Séries
#         </a></li><li class="header-nav-item"><a class="header-nav-link" data-jan='{"eventAction":"click","eventName":"internal","position_name":"navigation_menu_click","filters_value":"https:\/\/www.allocine.fr\/"}' href="/streaming/" title="Streaming">
#             Streaming
#         </a></li><li class="header-nav-item"><span class="ACrL3RACr2YWN0dS8= header-nav-link" title="TVActu">
#             TVActu
#         </span></li><li class="header-nav-item"><a class="header-nav-link" href="/trailer/" title="Trailers">
#             Trailers
#         </a></li><li class="header-nav-item"><a class="header-nav-link" href="/vod/" title="VOD">
#             VOD
#         </a></li><li class="header-nav-item"><a class="header-nav-link" href="/film/lesindes/" title="Les indés">
#             Les indés
#         </a></li><li class="header-nav-item"><span class="ACrL21ACr5Y2FuYWwv header-nav-link" title="Canal+">
#             Canal+
#         </span></li></ul><h1 class="header-main-subnav-holder"><div class="header-main-ephemeride">Découvrez notre recherche de <a href="/salle/">séances cinéma</a>, les <a href="/news/">news</a> et <a href="/dossiers/">dossiers</a> cinéma et séries TV, les <a href="/video/">émissions AlloCiné</a>, les <a href="/video/bandes-annonces/plus-recentes/">dernières bandes-annonces</a> et plus encore...</div></h1></nav><div class="header-userspace-nav" id="header-userspace-nav"><span aria-label="Bouton Mon compte" class="ACrLy9ACrtb24uYWxsb2NpbmUuZnIv header-nav-userspace-upper-link"><img alt="" class="avatar js-myaccount-avatar" src="..."/>
#                     Mon compte
#                 </span><div class="header-nav-userspace-holder"><div class="header-nav-userspace-sso"><span class="ACrLy9ACrtb24uYWxsb2NpbmUuZnIvY29ubmV4aW9uLz9yZXR1cm5Vcmw9aHR0cHMlM0ElMkYlMkZ3d3cuYWxsb2NpbmUuZnIlMkY= button button-social-ac-ghost button-sm sign-in"><span class="txt">Identifiez-vous</span></span><span class="ACrLy9ACrtb24uYWxsb2NpbmUuZnIvaW5zY3JpcHRpb24vP3JldHVyblVybD0lMkYlMkZtb24uYWxsb2NpbmUuZnIlMkY= button button-social-ac-full button-sm sign-up"><span class="txt">Créez votre compte</span></span></div><ul class="header-nav-userspace-subcontent"></ul></div></div> </div>
# </div>
# </header>
# <div class="main-banner">
# <div class="js-masthead ad-masthead ad-item" id="dfp-masthead"></div>
# </div>
# <main class="content-layout homepage-layout cf" id="content-layout" role="main">
# <div class="carousel carousel-main carousel-full js-carousel" data-auto="true"><div class="carousel-row carousel-main-row"><figure class="carousel-item carousel-main-item current" data-emergence="1" data-ga-trigger="impression" data-index="1" data-jan='{"brand_campaign_id":12553,"brand_campaign_name":"emergence_theater_dragons","brand_campaign_position":"carouselitem","brand_campaign_position_type":"carousel_item","brand_campaign_type":"emergence","eventName":"emergence","movie_entity":"313481|dragons","eventAction":"impression"}'><span class="ACraHRACr0cHM6Ly93d3cuYWxsb2NpbmUuZnIvYXJ0aWNsZS9maWNoZWFydGljbGVfZ2VuX2NhcnRpY2xlPTEwMDAxMjg3NTUuaHRtbA== carousel-main-img-holder" data-ga-trigger="clic" data-jan='[{"content_entity":"undefined","eventAction":"click","eventName":"internal","filters_value":"https:\/\/www.allocine.fr\/article\/fichearticle_gen_carticle=1000128755.html","position_name":"news_carousel","site_route":"homepage"},{"brand_campaign_id":12553,"brand_campaign_name":"emergence_theater_dragons","brand_campaign_position":"carouselitem","brand_campaign_position_type":"carousel_item","brand_campaign_type":"emergence","eventName":"emergence","movie_entity":"313481|dragons","eventAction":"click"}]'><img class="carousel-main-image" height="400" src="https://fr.web.img6.acsta.net/img/22/d5/22d5e2479e723b3a623139a7e4cb3ac0.jpg" title="Une aventure aussi spectaculaire qu'émouvante" width="1024"/></span><figcaption class="carousel-main-content"><span class="ACraHRACr0cHM6Ly93d3cuYWxsb2NpbmUuZnIvYXJ0aWNsZS9maWNoZWFydGljbGVfZ2VuX2NhcnRpY2xlPTEwMDAxMjg3NTUuaHRtbA== title" data-ga-trigger="clic" data-jan='[{"content_entity":"undefined","eventAction":"click","eventName":"internal","filters_value":"https:\/\/www.allocine.fr\/article\/fichearticle_gen_carticle=1000128755.html","position_name":"news_carousel","site_route":"homepage"},{"brand_campaign_id":12553,"brand_campaign_name":"emergence_theater_dragons","brand_campaign_position":"carouselitem","brand_campaign_position_type":"carousel_item","brand_campaign_type":"emergence","eventName":"emergence","movie_entity":"313481|dragons","eventAction":"click"}]' title="Une aventure aussi spectaculaire qu'émouvante">Une aventure aussi spectaculaire qu'émouvante</span><div class="desc">Vivez l’expérience Dragons, dès le 11 juin au cinéma !</div></figcaption></figure><figure class="carousel-item carousel-main-item" data-index="2"><span class="ACraHRACr0cHM6Ly93d3cuYWxsb2NpbmUuZnIvYXJ0aWNsZS9maWNoZWFydGljbGVfZ2VuX2NhcnRpY2xlPTEwMDAxMzYwMjUuaHRtbA== carousel-main-img-holder" data-ga-trigger="clic" data-jan='{"content_entity":"undefined","eventAction":"click","eventName":"internal","filters_value":"https:\/\/www.allocine.fr\/article\/fichearticle_gen_carticle=1000136025.html","position_name":"news_carousel","site_route":"homepage"}'><img class="carousel-main-image" data-src="https://fr.web.img3.acsta.net/img/7c/95/7c95b6db6102dd39c5ced94eb0dc3993.jpg" height="400" src="..." title="Un huis clos familial d’un réalisme poignant" width="1024"/></span><figcaption class="carousel-main-content"><span class="ACraHRACr0cHM6Ly93d3cuYWxsb2NpbmUuZnIvYXJ0aWNsZS9maWNoZWFydGljbGVfZ2VuX2NhcnRpY2xlPTEwMDAxMzYwMjUuaHRtbA== title" data-ga-trigger="clic" data-jan='{"content_entity":"undefined","eventAction":"click","eventName":"internal","filters_value":"https:\/\/www.allocine.fr\/article\/fichearticle_gen_carticle=1000136025.html","position_name":"news_carousel","site_route":"homepage"}' title="Un huis clos familial d’un réalisme poignant">Un huis clos familial d’un réalisme poignant</span><div class="desc">Deux Sœurs est à découvrir en salle dès maintenant.</div></figcaption></figure><figure class="carousel-item carousel-main-item" data-index="3"><span class="ACraHRACr0cHM6Ly93d3cuYWxsb2NpbmUuZnIvYXJ0aWNsZS9maWNoZWFydGljbGVfZ2VuX2NhcnRpY2xlPTEwMDAxMzYzMzUuaHRtbA== carousel-main-img-holder" data-ga-trigger="clic" data-jan='{"content_entity":"undefined","eventAction":"click","eventName":"internal","filters_value ...
# <section class="section section-wrap">
# <div class="titlebar titlebar-top-border titlebar-page"><h2 class="titlebar-title titlebar-title-xl"><span class="ACrL2ZACrpbG0v titlebar-link">Cinéma</span></h2></div>
# <nav aria-label="navigation secondaire" class="third-nav third-nav-hash js-third-nav" role="navigation">
# <a class="item" href="/film/agenda/">Agenda des sorties</a> <a class="item js-item-mq-medium" href="/kids/">Kids</a> <a class="item js-item-mq-medium" href="/film/meilleurs/">Meilleurs films</a> <a class="item js-item-mq-medium" href="/film/meilleurs/documentaires/">Meilleurs documentaires</a>
# <div class="item-more js-third-sub-nav-holder">
# <span aria-label="Afficher plus d'éléments" class="item-more-picto icon icon-plus-mini plus-mini-rounded js-trigger-third-nav-sub" role="button"></span>
# <div class="third-nav-sub js-third-nav-sub">
# <a class="item" href="/film/avantpremieres/">Avant-premières</a> <a class="item" href="/boxoffice/france/">Box Office</a> <a class="item" href="/film/enfants/aucinema/">Films pour enfants à l'affiche</a> <a class="item" href="/dvd/">DVD</a> <a class="item" href="/film/meilleurs/decennie-2010/annee-2019/">Meilleurs films 2019</a> <a class="item" href="/film/enfants/">Tous les films pour enfants</a> <a class="item" href="/films/">Tous les films</a> <span class="ACrL2ZACrlc3RpdmFscy8= item">Festivals</span> <span class="ACrL2ZACrpbG0vY291cnQtbWV0cmFnZS8= item">Court-métrages</span>
# </div>
# </div>
# </nav>
# <div aria-label="Rechercher une salle : Nice, Bastille, 75001, UGC Lyon ..." class="search-theater cf js-search-theater-push" data-placeholder="Rechercher une salle : Nice, Bastille, 75001, UGC Lyon ..." data-route='{"locationRoute":{"name":"theaters_localization","objectParameters":{"localization":"id"}},"theaterRoute":{"name":"theater_showtimes","objectParameters":{"idTheater":"internalId"}},"searchRoute":{"name":"theaters_result_search","defaultParameters":null}}'>
# <div class="js-search-location" data-placeholder="Rechercher une salle : Nice, Bastille, 75001, UGC Lyon ..." data-route='{"locationRoute":{"name":"theaters_localization","objectParameters":{"localization":"id"}},"theaterRoute":{"name":"theater_showtimes","objectParameters":{"idTheater":"internalId"}},"searchRoute":{"name":"theaters_result_search","defaultParameters":null}}'>
# <form action="/salle/recherche/" aria-label="formulaire de recherche d'une salle de cinéma" autocomplete="off" class="form-holder theaters-form form form-localization" method="get" role="form">
# <fieldset class="form-field">
# <input class="form-text" id="showtimes_search_q" name="showtimes_search[q]" placeholder="Rechercher une salle : Nice, Bastille, 75001, UGC Lyon ..." required="required" type="text"/>
# <button aria-label="Rechercher une salle : Nice, Bastille, 75001, UGC Lyon ..." class="form-submit button button-md icon icon-search" title="Rechercher une salle : Nice, Bastille, 75001, UGC Lyon ..." type="submit"></button>
# </fieldset>
# </form>
# </div>
# </div>
# </section>
# <section class="section section-wrap">
# <div class="gd gd-gap-20 gd-xs-12">
# <div class="gd-span-s-12 gd-span-l-1-8 gd-item-mw-0">
# <div class="mdl-inside">
# <div class="titlebar titlebar-arrow section-title"><h3 class="titlebar-title titlebar-title-md"><a class="titlebar-link" href="/film/sorties-semaine/">Sorties de la semaine</a></h3></div>
# <div class="roller-holder js-roller roller-arrow-title roller-hp" data-offset="20"><div class="roller-overflow"><div class="roller-slider"><div class="roller-item"><div class="card entity-card-simple"><figure class="thumbnail"><div class="thumbnail-layer"><div class="layer-link-holder"><span class="ACrL3NACrlYW5jZS9maWxtLTIyNzQ2My8= layer-link">Séances</span></div></div><span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0yMjc0NjMuaHRtbA== thumbnail-container thumbnail-link" title="Minecraft, Le Film"><img alt="poster de Minecraft, Le Film" class="thumbnail-img" height="200" src="https://fr.web.img6.acsta.net/c_150_200/img/3e/61/3e619c6423fd2c82be9ec8b727aa217b.jpg" width="150"/></span></figure><div class="meta"><a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=227463.html" title="Minecraft, Le Film">Minecraft, Le Film</a><div class="meta-description light">
#
#
#
#     De Jared Hess
# </div></div></div></div><div class="roller-item"><div class="card entity-card-simple"><figure class="thumbnail"><div class="thumbnail-layer"><div class="layer-link-holder"><span class="ACrL3NACrlYW5jZS9maWxtLTMyMTYwMy8= layer-link">Séances</span></div></div><span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0zMjE2MDMuaHRtbA== thumbnail-container thumbnail-link" title="Le Routard"><img alt="poster de Le Routard" class="thumbnail-img" height="200" src="https://fr.web.img5.acsta.net/c_150_200/img/f3/26/f326fa10630f536e404af5ec4e6b8c39.jpg" width="150"/></span></figure><div class="meta"><a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=321603.html" title="Le Routard">Le Routard</a><div class="meta-description light">
#
#
#
#     De Philippe Mechelen
# </div></div></div></div><div class="roller-item"><div class="card entity-card-simple"><figure class="thumbnail"><div class="thumbnail-layer"><div class="layer-link-holder"><span class="ACrL3NACrlYW5jZS9maWxtLTI5NDg0Ny8= layer-link">Séances</span></div></div><span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0yOTQ4NDcuaHRtbA== thumbnail-container thumbnail-link" title="Ozi, la voix de la forêt"><img alt="poster de Ozi, la voix de la forêt" class="thumbnail-img" height="200" src="https://fr.web.img4.acsta.net/c_150_200/img/60/b0/60b0291b84a5c7fe4ebd7e8495f2a471.jpg" width="150"/></span></figure><div class="meta"><a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=294847.html" title="Ozi, la voix de la forêt">Ozi, la voix de la forêt</a><div class="meta-description light">
#
#
#
#     De Tim Harper
# </div></div></div></div><div class="roller-item"><div class="card entity-card-simple"><figure class="thumbnail"><div class="thumbnail-layer"><div class="layer-link-holder"><span class="ACrL3NACrlYW5jZS9maWxtLTI1OTE1Ny8= layer-link">Séances</span></div></div><span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0yNTkxNTcuaHRtbA== thumbnail-container thumbnail-link" title="Natacha (presque) hôtesse de l’air"><img alt="poster de Natacha (presque) hôtesse de l’air" class="thumbnail-img" data-src="https://fr.web.img3.acsta.net/c_150_200/img/ee/7d/ee7d955a04a6af1247803f18ea8791a8.jpg" height="200" src="..." width="150"/></span></figure><div class="meta"><a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=259157.html" title="Natacha (presque) hôtesse de l’air">Natacha (presque) hôtesse de l’air</a><div class="meta-description light">
#
#
#
#     De Noémie Saglio
# </div></div></div></div><div class="roller-item"><div class="card entity-card-simple"><figure class="thumbnail"><div class="thumbnail-layer"><div class="layer-link-holder"><span class="ACrL3NACrlYW5jZS9maWxtLTEwMDAwMTYxNjAv layer-link">Séances</span></div></div><span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0xMDAwMDE2MTYwLmh0bWw= thumbnail-container thumbnail-link" title="Shaka Ponk – The final fucked up tour - Le final au cinéma"><img alt="poster de Shaka Ponk – The final fucked up tour - Le final au cinéma" class="thumbnail-img" data-src="https://fr.web.img3.acsta.net/c_150_200/img/e2/2c/e22cde61fa93673c5017598d1957b289.jpg" height="200" src="..." width="150"/></span></figure><div class="meta"><a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=1000016160.html" title="Shaka Ponk – The final fucked up tour - Le final au cinéma">Shaka Ponk – The final fucked up tour - Le final au cinéma</a><div class="meta-description light">
#
#
#
#     De directeur inconnu
# </div></div></div></div><div class="roller-item"><div class="card entity-card-simple"><figure class="thumbnail"><div class="thumbnail-layer"><div class="layer-link-holder"><span class="ACrL3NACrlYW5jZS9maWxtLTMxMDExMS8= layer-link">Séances</span></div></div><span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0zMTAxMTEuaHRtbA== thumbnail-container thumbnail-link" title="Lads"><img alt="poster de Lads" class="thumbnail-img" data-src="https://fr.web.img4.acsta.net/c_150_200/img/ab/d8/abd8256094c5c7f6dea5f55028e796dc.jpg" height="200" src="..." width="150"/></span></figure><div class="meta"><a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=310111.html" title="Lads">Lads</a><div class="meta-description light">
#
#
#
#     De Julien Menanteau
# </div></div></div></div><div class="roller-item"><div class="card entity-card-simple"><figure class="thumbnail"><div class="thumbnail-layer"><div class="layer-link-holder"><span class="ACrL3NACrlYW5jZS9maWxtLTMxNjIzNS8= layer-link">Séances</span></div></div><span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0zMTYyMzUuaHRtbA== thumbnail-container thumbnail-link" title="Deux sœurs"><img alt="poster de Deux sœurs" class="thumbnail-img" data-src="https://fr.web.img2.acsta.net/c_150_200/img/e4/24/e42470432353d51aee08b57c0eb40fa8.jpg" height="200" src="..." width="150"/></span></figure><div class="meta"><a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=316235.html" title="Deux sœurs">Deux sœurs</a><div class="meta-description light">
#
#
#
#     De Mike Leigh
# </div></div></div></div><div class="roller-item"><div class="card entity-card-simple"><figure class="thumbnail"><div class="thumbnail-layer"><div class="layer-link-holder"><span class="ACrL3NACrlYW5jZS9maWxtLTMxODI2NS8= layer-link">Séances</span></div></div><span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0zMTgyNjUuaHRtbA== thumbnail-container thumbnail-link" title="Cassandre"><img alt="poster de Cassandre" class="thumbnail-img" data-src="https://fr.web.img5.acsta.net/c_150_200/img/d0/6a/d06a7296aae7b673f6b08eced87a653c.jpg" height="200" src="..." width="150"/></span></figure><div class="meta"><a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=318265.html" title="Cassandre">Cassandre</a><div class="meta-description light">
#
#
#
#     De Hélène Merlin
# </div></div></div></div><div class="roller-item"><div class="card entity-card-simple"><figure class="thumbnail"><div class="thumbnail-layer"><div class="layer-link-holder"><span class="ACrL3NACrlYW5jZS9maWxtLTEwMDAwMTk2MTgv layer-link">Séances</span></div></div><span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0xMDAwMDE5NjE4Lmh0bWw= thumbnail-container thumbnail-link" title="Nous voilà grands !"><img alt="poster de Nous voilà grands !" class="thumbnail-img" data-src="https://fr.web.img6.acsta.net/c_150_200/img/7b/a8/7ba86b966a75067306c0c31bd757654a.jpg" height="200" src="..." width="150"/></span></figure><div class="meta"><a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=1000019618.html" title="Nous voilà grands !">Nous voilà grands !</a><div class="meta-description light">
#
#
#
#     De Stina Wirsén, Linda Hambäck
# </div></div></div></div><div class="roller-item"><div class="card entity-card-simple"><figure class="thumbnail"><div class="thumbnail-layer"><div class="layer-link-holder"><span class="ACrL3NACrlYW5jZS9maWxtLTMyNTE3MS8= layer-link">Séances</span></div></div><span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0zMjUxNzEuaHRtbA== thumbnail-container thumbnail-link" title="Au pays de nos frères"><img alt="poster de Au pays de nos frères" class="thumbnail-img" data-src="https://fr.web.img6.acsta.net/c_150_200/img/fb/9e/fb9ee9883d7e627c3c1e7ab951c118f3.jpg" height="200" src="..." width="150"/></span></figure><div class="meta"><a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=325171.html" title="Au pays de nos frères">Au pays de nos frères</a><div class="meta-description light">
#
#
#
#     De Raha Amirfazli, Alireza Ghasemi
# </div></div></div></div><div class="roller-item"><div class="card entity-card-simple"><figure class="thumbnail"><div class="thumbnail-layer"><div class="layer-link-holder"><span class="ACrL3NACrlYW5jZS9maWxtLTEwMDAwMTY1ODIv layer-link">Séances</span></div></div><span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0xMDAwMDE2NTgyLmh0bWw= thumbnail-container thumbnail-link" title="Fanon"><img alt="poster de Fanon" class="thumbnail-img" data-src="https://fr.web.img3.acsta.net/c_150_200/img/07/1e/071ef5af8140fb6eb9fb4be01175c7a5.jpg" height="200" src="..." width="150"/></span></figure><div class="meta"><span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0xMDAwMDE2NTgyLmh0bWw= meta-title meta-title-link" title="Fanon">Fanon</span><div class="meta-description light">
#
#
#
#     De Jean-Claude Barny
# </div></div></div></div><div class="roller-item"><div class="card entity-card-simple"><figure class="thumbnail"><div class="thumbnail-layer"><div class="layer-link-holder"><span class="ACrL3NACrlYW5jZS9maWxtLTEwMDAwMDEyNjAv layer-link">Séances</span></div></div><span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0xMDAwMDAxMjYwLmh0bWw= thumbnail-container thumbnail-link" title="Ce n'est qu'un au revoir"><img alt="poster de Ce n'est qu'un au revoir" class="thumbnail-img" data-src="https://fr.web.img5.acsta.net/c_150_200/img/16/b0/16b026e1857b68a2682a7171a5669b3b.jpg" height="200" src="..." width="150"/></span></figure><div class="meta"><span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0xMDAwMDAxMjYwLmh0bWw= meta-title meta-title-link" title="Ce n'est qu'un au revoir">Ce n'est qu'un au revoir</span><div class="meta-description light">
#
#
#
#     De Guillaume Brac
# </div></div></div></div><div class="roller-item"><div class="card entity-card-simple"><figure class="thumbnail"><div class="thumbnail-layer"><div class="layer-link-holder"><span class="ACrL3NACrlYW5jZS9maWxtLTEwMDAwMTk0OTQv layer-link">Séances</span></div></div><span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0xMDAwMDE5NDk0Lmh0bWw= thumbnail-container thumbnail-link" title="Colargol et le Cirque Pimoulu "><img alt="poster de Colargol et le Cirque Pimoulu " class="thumbnail-img" data-src="https://fr.web.img6.acsta.net/c_150_200/img/af/69/af692dd412da5fd219dbf64f2be705ee.jpg" height="200" src="..." width="150"/></span></figure><div class="meta"><span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0xMDAwMDE5NDk0Lmh0bWw= meta-title meta-title-link" title="Colargol et le Cirque Pimoulu ">Colargol et le Cirque Pimoulu </span><div class="meta-description light">
#
#
#
#     De Tadeusz Wilkosz, Jadwiga Kudrzycka
# </div></div></div></div><div class="roller-item"><div class="card entity-card-simple"><figure class="thumbnail"><div class="thumbnail-layer"><div class="layer-link-holder"><span class="ACrL3NACrlYW5jZS9maWxtLTEwMDAwMjA4NTIv layer-link">Séances</span></div></div><span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0xMDAwMDIwODUyLmh0bWw= thumbnail-container thumbnail-link" title="Seventeen [Right here] World Tour in cinemas"><img alt="poster de Seventeen [Right here] World Tour in cinemas" class="thumbnail-img" data-src="https://fr.web.img6.acsta.net/c_150_200/img/e2/3c/e23c99a29c653012401b66f25b6085c2.jpg" height="200" src="..." width="150"/></span></figure><div class="meta"><span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0xMDAwMDIwODUyLmh0bWw= meta-title meta-title-link" title="Seventeen [Right here] World Tour in cinemas">Seventeen [Right here] World Tour in cinemas</span><div class="meta-description light">
#
#
#
#     De Yoondong Oh
# </div></div></div></div><div class="roller-item"><div class="card entity-card-simple"><figure class="thumbnail"><div class="thumbnail-layer"><div class="layer-link-holder"><span class="ACrL3NACrlYW5jZS9maWxtLTMwMzkwOC8= layer-link">Séances</span></div></div><span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0zMDM5MDguaHRtbA== thumbnail-container thumbnail-link" title="The Grill"><img alt="poster de The Grill" class="thumbnail-img" data-src="https://fr.web.img2.acsta.net/c_150_200/img/98/27/9827f88d1e9ea5205d7787e307cdc518.jpg" height="200" src="..." width="150"/></span></figure><div class="meta"><span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0zMDM5MDguaHRtbA== meta-title meta-title-link" title="The Grill">The Grill</span><div class="meta-description light">
#
#
#
#     De Alonso Ruizpalacios
# </div></div></div></div></div></div><div class="roller-btn-holder"><button aria-label="Bouton aller vers la gauche" class="roller-btn btn-left icon icon-arrow-left disabled"></button><button aria-label="Bouton aller vers la droite" class="roller-btn btn-right icon icon-arrow-right"></button></div></div>
# <div class="end-section-link-container">
# <span class="ACrL2ZACrpbG0vc29ydGllcy1zZW1haW5lLw== end-section-link" title="Toutes les sorties de la semaine">Toutes les sorties de la semaine</span>
# </div>
# </div>
# <div class="mdl-outside">
# <div class="titlebar titlebar-arrow section-title"><h3 class="titlebar-title titlebar-title-md"><span class="ACrL2ZACrpbG0vYXVjaW5lbWEv titlebar-link">Toujours à l'affiche</span></h3></div>
# <div class="roller-holder js-roller roller-arrow-title roller-hp" data-offset="20"><div class="roller-overflow"><div class="roller-slider"><div class="roller-item"><div class="card entity-card-simple"><figure class="thumbnail"><div class="thumbnail-layer"><div class="layer-link-holder"><span class="ACrL3NACrlYW5jZS9maWxtLTMxNjk4NC8= layer-link">Séances</span></div></div><span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0zMTY5ODQuaHRtbA== thumbnail-container thumbnail-link" title="Ma Mère, Dieu et Sylvie Vartan"><img alt="poster de Ma Mère, Dieu et Sylvie Vartan" class="thumbnail-img" data-src="https://fr.web.img3.acsta.net/c_150_200/img/67/96/679692192682dfa81dc8296e92a4cbf5.jpg" height="200" src="..." width="150"/></span></figure><div class="meta"><a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=316984.html" title="Ma Mère, Dieu et Sylvie Vartan">Ma Mère, Dieu et Sylvie Vartan</a><div class="meta-description light">
#
#
#
#     De Ken Scott
# </div></div></div></div><div class="roller-item"><div class="card entity-card-simple"><figure class="thumbnail"><div class="thumbnail-layer"><div class="layer-link-holder"><span class="ACrL3NACrlYW5jZS9maWxtLTI1MTQyMS8= layer-link">Séances</span></div></div><span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0yNTE0MjEuaHRtbA== thumbnail-container thumbnail-link" title="Blanche Neige"><img alt="poster de Blanche Neige" class="thumbnail-img" data-src="https://fr.web.img2.acsta.net/c_150_200/img/9a/3b/9a3b1d10ddeff79af6d1d3dab41348ea.jpg" height="200" src="..." width="150"/></span></figure><div class="meta"><a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=251421.html" title="Blanche Neige">Blanche Neige</a><div class="meta-description light">
#
#
#
#     De Marc Webb
# </div></div></div></div><div class="roller-item"><div class="card entity-card-simple"><figure class="thumbnail"><div class="thumbnail-layer"><div class="layer-link-holder"><span class="ACrL3NACrlYW5jZS9maWxtLTI4OTIxNS8= layer-link">Séances</span></div></div><span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0yODkyMTUuaHRtbA== thumbnail-container thumbnail-link" title="On Ira"><img alt="poster de On Ira" class="thumbnail-img" data-src="https://fr.web.img6.acsta.net/c_150_200/img/4e/64/4e644edc4b90cae39ea31727a29cdb09.jpg" height="200" src="..." width="150"/></span></figure><div class="meta"><a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=289215.html" title="On Ira">On Ira</a><div class="meta-description light">
#
#
#
#     De Enya Baroux
# </div></div></div></div><div class="roller-item"><div class="card entity-card-simple"><figure class="thumbnail"><div class="thumbnail-layer"><div class="layer-link-holder"><span class="ACrL3NACrlYW5jZS9maWxtLTMyNjAxOS8= layer-link">Séances</span></div></div><span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0zMjYwMTkuaHRtbA== thumbnail-container thumbnail-link" title="Les Bodin’s partent en vrille"><img alt="poster de Les Bodin’s partent en vrille" class="thumbnail-img" data-src="https://fr.web.img2.acsta.net/c_150_200/img/2a/48/2a483a34b0e2019f6a77fcae72bfed4c.jpg" height="200" src="..." width="150"/></span></figure><div class="meta"><a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=326019.html" title="Les Bodin’s partent en vrille">Les Bodin’s partent en vrille</a><div class="meta-description light">
#
#
#
#     De Frédéric Forestier
# </div></div></div></div></div></div><div class="roller-btn-holder"><button aria-label="Bouton aller vers la gauche" class="roller-btn btn-left icon icon-arrow-left disabled"></button><button aria-label="Bouton aller vers la droite" class="roller-btn btn-right icon icon-arrow-right"></button></div></div>
# <div class="end-section-link-container">
# <a class="end-section-link" href="/film/aucinema/" title="Tous les films encore à l'affiche">Tous les films encore à l'affiche</a>
# </div>
# </div>
# <div class="banner-hp-wrapper">
# <div class="banner-hp-desktop">
# <span class="ACraHRACr0cHM6Ly93d3cuYWxsb2NpbmUuZnIvc2VhbmNlL2ZpbG0tMjk0ODQ3Lw==" data-ga-trigger="clic" data-jan='{"eventAction":"click","eventName":"internal","position_name":"banner_hp","filters_value":"https:\/\/www.allocine.fr\/seance\/film-294847\/"}' target="_blank">
# <img alt="Découvrez en plus avec AlloCiné" class="banner-hp-img" data-src="https://fr.web.img6.acsta.net/img/19/5e/195e5945ccdcc823ac7bafee411a20a4.jpg" src="..." width="664"/>
# </span>
# </div>
# <div class="banner-hp-mobile">
# <span class="ACraHRACr0cHM6Ly93d3cuYWxsb2NpbmUuZnIvc2VhbmNlL2ZpbG0tMjk0ODQ3Lw==" data-ga-trigger="clic" data-jan='{"eventAction":"click","eventName":"internal","position_name":"banner_hp","filters_value":"https:\/\/www.allocine.fr\/seance\/film-294847\/"}' target="_blank">
# <img alt="Découvrez en plus avec AlloCiné" class="banner-hp-img" data-src="https://fr.web.img5.acsta.net/img/a7/cb/a7cb8a91a218b128f605000cf79613b4.jpg" src="..." width="420"/>
# </span>
# </div>
# </div>
# </div>
# <div class="gd-span-s-12 gd-span-l-9-4">
# <div id="mobile-referrer-atf"></div>
# <div class="movie-next">
# <div class="titlebar section-title"><h3 class="titlebar-title titlebar-title-md"><span class="ACrL2ZACrpbG0vYXR0ZW5kdXMv titlebar-link">Prochainement</span></h3><div class="light titlebar-subtile"><span class="titlebar-subtile-txt">Classement des films les plus consultés hier</span></div></div>
# <ul class="list-entity list-movie-hp small-crop mdl-fixed">
# <li class="list-entity-item list-entity-item-first cf">
# <figure class="thumbnail">
# <span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0zMTM2NzIuaHRtbA== thumbnail-container thumbnail-link" title="Piégé">
# <img alt="image de la vidéo Piégé" class="thumbnail-img" data-src="https://fr.web.img5.acsta.net/c_120_160/img/ff/cc/ffccff89de32b9e8867430cb8ac31cef.jpg" height="160" src="..." width="120"/>
# </span>
# </figure>
# <div class="meta">
# <div class="title-wrapper">
# <a class="list-entity-item-link" href="/film/fichefilm_gen_cfilm=313672.html"> Piégé </a>
# </div>
# </div>
# </li>
# <li class="list-entity-item">
# <div class="title-wrapper">
# <a class="list-entity-item-link" href="/film/fichefilm_gen_cfilm=317103.html"> Zion </a>
# </div>
# </li>
# <li class="list-entity-item">
# <div class="title-wrapper">
# <a class="list-entity-item-link" href="/film/fichefilm_gen_cfilm=325691.html"> Moon le panda </a>
# </div>
# </li>
# <li class="list-entity-item">
# <div class="title-wrapper">
# <a class="list-entity-item-link" href="/film/fichefilm_gen_cfilm=1000000495.html"> Rapide </a>
# </div>
# </li>
# <li class="list-entity-item">
# <div class="title-wrapper">
# <a class="list-entity-item-link" href="/film/fichefilm_gen_cfilm=1000004184.html"> La Réparation </a>
# </div>
# </li>
# <li class="more-trigger js-more-trigger">Voir plus de films</li>
# <li class="row more-hidden">
# <ul>
# <li class="list-entity-item">
# <div class="title-wrapper">
# <span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0xMDAwMDE3NDc4Lmh0bWw= list-entity-item-link"> Ne Zha 2 </span>
# </div>
# </li>
# <li class="list-entity-item">
# <div class="title-wrapper">
# <span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0zMTM1NTAuaHRtbA== list-entity-item-link"> The Amateur </span>
# </div>
# </li>
# <li class="list-entity-item">
# <div class="title-wrapper">
# <span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0xMDAwMDAzODI3Lmh0bWw= list-entity-item-link"> Doux Jésus </span>
# </div>
# </li>
# <li class="list-entity-item">
# <div class="title-wrapper">
# <span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0yNzA5MzYuaHRtbA== list-entity-item-link"> Mission : Impossible – The Final Reckoning </span>
# </div>
# </li>
# <li class="list-entity-item">
# <div class="title-wrapper">
# <span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT0yNjgzNjIuaHRtbA== list-entity-item-link"> Lilo &amp; Stitch </span>
# </div>
# </li>
# </ul>
# </li>
# </ul>
# <div class="end-section-link-container">
# <a class="end-section-link" href="/film/attendus/" title="Tous les films à venir">Tous les films à venir</a>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="section section-wrap">
# <style>
#             :root {
#                 --customAnchorPlusTxtColor: #000000;
#         }
#
#     /* Mobile */
#     .anchor-plus {
#         background-image: url(https://fr.web.img2.acsta.net/img/b7/34/b734b5e70ba4d3088235cdf16c1067ba.jpg);
#     }
#
#     /* Desktop/Tablet */
#     .anchor-plus::before {
#         background-image: url(https://fr.web.img5.acsta.net/img/ee/b0/eeb0d65a8930bbdaf168934f83ea6764.jpg);
#     }
#
#     /* Desktop HP */
#     .anchor-plus.anchor-hp::after {
#         background-image: url(https://fr.web.img5.acsta.net/img/df/c2/dfc234f72cc166c5c24c52afe58c9d10.jpg);
#     }
# </style>
# <div class="js-anchor-plus anchor-plus anchor-hp hide-anchor-pos" data-cta-text-after-release="RESERVEZ VOTRE SEANCE" data-cta-text-before-release="DECOUVRIR LE FILM" data-display-showtimes="1" data-entity-id="321603" data-entity-release="2025-04-02" data-entity-title="Le Routard" data-entity-type="Movie" data-jan='{"brand_campaign_type":"ticket_anchor","brand_campaign_name":"e-ticketing_le_routard","brand_campaign_id":12545,"brand_campaign_position":"anchor_t_o_discovery_hp"}' data-operation-link="ACraHRACr0cHM6Ly93d3cuYWxsb2NpbmUuZnIvc2VhbmNlL2ZpbG0tMzIxNjAzLw==" data-text-after-release="EXCLUSIVEMENT AU CINEMA" data-text-before-release="PROCHAINEMENT AU CINÉMA"></div>
# </section>
# <section class="section section-wrap">
# <div class="titlebar section-title"><h3 class="titlebar-title titlebar-title-md"><a class="titlebar-link" href="/news/cinema/">Dernières news cinéma</a></h3></div>
# <div class="gd gd-gap-15 gd-xs-1 gd-m-3">
# <div class="card news-card news-card-col news-card news-card-list cf" data-ga-trigger="impression" data-jan='{"brand_campaign_id":12553,"brand_campaign_name":"emergence_theater_dragons","brand_campaign_position":"news","brand_campaign_position_type":"news_anchor","brand_campaign_type":"emergence","eventName":"emergence","movie_entity":"313481|dragons","eventAction":"impression"}'><figure class="thumbnail"><div class="thumbnail-container"><img alt="image de la news C'est l'un des plus grands films d'animation de ces 15 dernières années et il est de retour en prises de vues réelles : découvrez la nouvelle bande-annonce de Dragons" class="thumbnail-img" data-src="https://fr.web.img5.acsta.net/c_400_225/img/18/42/18420469544e3754215f1a9bdfcfcafc.jpg" height="225" src="..." width="400"/></div></figure><div class="meta"><div class="meta-category">News - Vu sur le web</div><div class="meta-title"><a class="meta-title-link" data-ga-trigger="clic" data-jan='{"brand_campaign_id":12553,"brand_campaign_name":"emergence_theater_dragons","brand_campaign_position":"news","brand_campaign_position_type":"news_anchor","brand_campaign_type":"emergence","eventName":"emergence","movie_entity":"313481|dragons","eventAction":"click"}' href="/article/fichearticle_gen_carticle=1000128755.html">C'est l'un des plus grands films d'animation de ces 15 dernières années et il est de retour en prises de vues réelles : découvrez la nouvelle bande-annonce de Dragons</a></div><div class="meta-date">jeudi 13 février 2025</div></div></div>
# <div class="card news-card news-card-col news-card news-card-list cf"><figure class="thumbnail no-thumb"><div class="thumbnail-container"><img alt="image de la news Ce soir à la télé : ni Incassable, ni Sixième Sens, ce thriller reste l'un des meilleurs films de Shyamalan" class="thumbnail-img" data-src="https://fr.web.img3.acsta.net/c_400_225/img/fd/da/fddacea558d813b2e09983d6441b2234.jpg" height="225" src="..." width="400"/></div></figure><div class="meta"><div class="meta-category">News - Films à la TV</div><div class="meta-title"><a class="meta-title-link" href="/article/fichearticle_gen_carticle=1000134999.html">Ce soir à la télé : ni Incassable, ni Sixième Sens, ce thriller reste l'un des meilleurs films de Shyamalan</a></div><div class="meta-date">jeudi 3 avril 2025</div></div></div>
# <div class="card news-card news-card-col news-card news-card-list cf"><figure class="thumbnail no-thumb no-thumb"><div class="thumbnail-container"><img alt="image de la news Jurassic Park : pendant 32 ans, personne n'a jamais vraiment fait attention à ce personnage, et pourtant ce n'est pas n'importe qui" class="thumbnail-img" data-src="https://fr.web.img4.acsta.net/c_400_225/img/22/7d/227d0674822b68c2e1a43f289f019a4d.jpg" height="225" src="..." width="400"/></div></figure><div class="meta"><div class="meta-category">News - Culture ciné</div><div class="meta-title"><a class="meta-title-link" href="/article/fichearticle_gen_carticle=1000134940.html">Jurassic Park : pendant 32 ans, personne n'a jamais vraiment fait attention à ce personnage, et pourtant ce n'est pas n'importe qui</a></div><div class="meta-date">mercredi 2 avril 2025</div></div></div>
# <div class="card news-card news-card-col news-card news-card-list cf"><figure class="thumbnail no-thumb no-thumb no-thumb"><div class="thumbnail-container"><img alt="image de la news Quiz Cinéma : tente de reconnaître ces 10 films avec une seule image !" class="thumbnail-img" data-src="https://fr.web.img3.acsta.net/c_400_225/img/39/f0/39f04a6e675f209ea941b51f596324c8.jpg" height="225" src="..." width="400"/></div></figure><div class="meta"><div class="meta-category">News - Culture ciné</div><div class="meta-title"><a class="meta-title-link" href="/article/fichearticle_gen_carticle=1000134723.html">Quiz Cinéma : tente de reconnaître ces 10 films avec une seule image !</a></div><div class="meta-date">mercredi 2 avril 2025</div></div></div>
# <div class="card news-card news-card-col news-card news-card-list cf"><figure class="thumbnail no-thumb no-thumb no-thumb no-thumb"><div class="thumbnail-container"><img alt="image de la news Il y a 19 ans, en pleine interview pour son nouveau film, ce légendaire réalisateur s'est fait tirer dessus !" class="thumbnail-img" data-src="https://fr.web.img5.acsta.net/c_400_225/img/62/e7/62e7774f07a70874017c5d99d53c93c9.jpg" height="225" src="..." width="400"/></div></figure><div class="meta"><div class="meta-category">News - Stars</div><div class="meta-title"><a class="meta-title-link" href="/article/fichearticle_gen_carticle=1000137109.html">Il y a 19 ans, en pleine interview pour son nouveau film, ce légendaire réalisateur s'est fait tirer dessus !</a></div><div class="meta-date">mercredi 2 avril 2025</div></div></div>
# <div class="card news-card news-card-col news-card news-card-list cf"><figure class="thumbnail no-thumb no-thumb no-thumb no-thumb no-thumb"><div class="thumbnail-container"><img alt="image de la news 15 ans après, ce film Disney noté 4,2 sur 5 pourrait faire son retour au cinéma avec une star planétaire" class="thumbnail-img" data-src="https://fr.web.img5.acsta.net/c_400_225/img/9b/f2/9bf2aaa3a9e96161f57d570056697518.jpg" height="225" src="..." width="400"/></div></figure><div class="meta"><div class="meta-category">News - Tournages</div><div class="meta-title"><a class="meta-title-link" href="/article/fichearticle_gen_carticle=1000136865.html">15 ans après, ce film Disney noté 4,2 sur 5 pourrait faire son retour au cinéma avec une star planétaire</a></div><div class="meta-date">mercredi 2 avril 2025</div></div></div>
# <div class="card news-card news-card-col news-card news-card-list cf"><figure class="thumbnail no-thumb no-thumb no-thumb no-thumb no-thumb no-thumb"><div class="thumbnail-container"><img alt="image de la news Biopic sur les Beatles : voici les 4 acteurs qui incarneront les membres du groupe mythique au cinéma !" class="thumbnail-img" data-src="https://fr.web.img6.acsta.net/c_400_225/img/ce/28/ce2836b79407295aa6e8de46dcce60b0.jpg" height="225" src="..." width="400"/></div></figure><div class="meta"><div class="meta-category">News - Tournages</div><div class="meta-title"><span class="ACrL2FACrydGljbGUvZmljaGVhcnRpY2xlX2dlbl9jYXJ0aWNsZT0xMDAwMTM2ODQ3Lmh0bWw= meta-title-link">Biopic sur les Beatles : voici les 4 acteurs qui incarneront les membres du groupe mythique au cinéma !</span></div><div class="meta-date">mercredi 2 avril 2025</div></div></div>
# <div class="card news-card news-card-col news-card news-card-list cf"><figure class="thumbnail no-thumb no-thumb no-thumb no-thumb no-thumb no-thumb no-thumb"><div class="thumbnail-container"><img alt="image de la news &quot;Des émotions très fortes jusqu'au dernier plan&quot; : noté 4,1 sur 5, c'est le meilleur film d’Amanda Seyfried !" class="thumbnail-img" data-src="https://fr.web.img3.acsta.net/c_400_225/img/55/20/5520091ca7bd18826ffc59dc1f8bb738.jpg" height="225" src="..." width="400"/></div></figure><div class="meta"><div class="meta-category">News - Streaming</div><div class="meta-title"><span class="ACrL2FACrydGljbGUvZmljaGVhcnRpY2xlX2dlbl9jYXJ0aWNsZT0xMDAwMTM2MTg5Lmh0bWw= meta-title-link">"Des émotions très fortes jusqu'au dernier plan" : noté 4,1 sur 5, c'est le meilleur film d’Amanda Seyfried !</span></div><div class="meta-date">mercredi 2 avril 2025</div></div></div>
# <div class="card news-card news-card-col news-card news-card-list cf"><figure class="thumbnail no-thumb no-thumb no-thumb no-thumb no-thumb no-thumb no-thumb no-thumb"><div class="thumbnail-container"><img alt="image de la news C'est l'une des meilleures scènes d’action du cinéma : après ça, vous ne verrez plus jamais votre cuisine de la même manière !" class="thumbnail-img" data-src="https://fr.web.img6.acsta.net/c_400_225/img/02/ec/02ecc0ecfaaf75e7f5b8c24981b6953d.jpg" height="225" src="..." width="400"/></div></figure><div class="meta"><div class="meta-category">News - Culture ciné</div><div class="meta-title"><span class="ACrL2FACrydGljbGUvZmljaGVhcnRpY2xlX2dlbl9jYXJ0aWNsZT0xMDAwMTM0MDkzLmh0bWw= meta-title-link">C'est l'une des meilleures scènes d’action du cinéma : après ça, vous ne verrez plus jamais votre cuisine de la même manière !</span></div><div class="meta-date">mercredi 2 avril 2025</div></div></div> </div>
# <div class="end-section-link-container">
# <span class="ACrL25ACrld3MvY2luZW1hLw== end-section-link no-mg-bottom" title="Toutes les news cinéma">Toutes les news cinéma</span>
# <a class="end-section-link no-mg-bottom, hidden-xs" href="/dossiers/cinema/" title="Tous les dossiers cinéma">Tous les dossiers cinéma</a>
# </div>
# </section>
# <!-- TODO : Ask BOCMS Team to remove handle of background_color class in the CMS for emergence countdown admin, this var is not used anymore since we refacto this module -->
# <style>
#     :root {
#      --customEmergenceCountdownTHEATERTxtColor: #ffffff;     --customEmergenceCountdownTHEATERTimeLabelColor: #ffffff;     --customEmergenceCountdownTHEATERBtnBgColor: #fecc00;     --customEmergenceCountdownTHEATERBtnBgColorHover: #fecc00;     --customEmergenceCountdownTHEATERBtnTxtColor: #000000;    }
#
#     .emergence-countdown-theater .emergence-countdown::before {
#         background-image: url(https://fr.web.img3.acsta.net/img/0f/ea/0fea72ab2a1715ed437afbc359354b90.png);
#     }
#
#     .emergence-countdown-theater .emergence-countdown::after {
#         background-image: url(https://fr.web.img2.acsta.net/img/58/5b/585b357b8af8740ea498e9ff30c8d96d.png);
#     }
# </style>
# ...
# <span class="ACraHRACr0cDovL3NwZWNzLndlYmVkaWEuZnI=" rel="noopener" target="_blank">Publicité</span> <span class="pipe">|</span>
# <span class="ACrL3NACrlcnZpY2UvY29uZGl0aW9ucy5odG1s">CGU</span> <span class="pipe">|</span>
# <span class="ACrL3NACrlcnZpY2UvY29va2llcy5odG1s">Politique de cookies</span> <span class="pipe">|</span>
# <a class="cookie-notice" href="#">Préférences cookies</a> <span class="pipe">|</span>
# <span class="ACrL3NACrlcnZpY2UvY2hhcnRlLmh0bWw=">Données Personnelles</span> <span class="pipe">|</span>
# <span class="ACrL3NACrlcnZpY2Uvbm90ZS1wcmVzc2UuaHRtbA==">Revue de presse</span> <span class="pipe">|</span>
# <span class="ACrL3NACrlcnZpY2Uv">Les services AlloCiné</span> <span class="pipe">|</span>
# <span class="ACrL3NACrlcnZpY2UvZ2VyZXItdXRpcS5odG1s">Gérer Utiq</span> <span class="pipe">|</span>
#     ©AlloCiné
# </p>
# <p class="info">
#     Retrouvez tous les horaires et infos de votre cinéma sur le numéro AlloCiné : <span class="phone">0 892 892 892</span> (0,90€/minute)
# </p>
# <p class="info-logo">
# <i class="logo-footer footer-logo-brand"></i>
# <i class="logo-footer footer-logo-boxoffice"></i>
# <i class="logo-footer footer-logo-webedia"></i>
# </p>
# </div>
# </footer>
# <div class="mq-state" id="mq-state"></div>
# <div class="message-board">
# <div class="js-message-board"></div>
# </div>
# <a aria-label="Retour en haut de la page" class="back-top icon icon-arrow-top" href="#allocine__homepage" id="back-top">
# <span class="no-icon">Back to Top</span>
# </a>
# <div class="easyAdsBox"> </div>
# <div id="modal-anchors-container">
# </div>
# <!-- DIDOMI GLOBALS -->
# <script type="text/javascript">
#     window.didomiOnReady = window.didomiOnReady || [];
#     window.didomiEventListeners = window.didomiEventListeners || [];
# </script>
# <!-- DIDOMI CMP SCRIPT WITH PAYWAL -->
# <script type="text/javascript">window.gdprAppliesGlobally=true;(function(){function a(e){if(!window.frames[e]){if(document.body&&document.body.firstChild){var t=document.body;var n=document.createElement("iframe");n.style.display="none";n.name=e;n.title=e;t.insertBefore(n,t.firstChild)}
#     else{setTimeout(function(){a(e)},5)}}}function e(n,r,o,c,s){function e(e,t,n,a){if(typeof n!=="function"){return}if(!window[r]){window[r]=[]}var i=false;if(s){i=s(e,t,n)}if(!i){window[r].push({command:e,parameter:t,callback:n,version:a})}}e.stub=true;function t(a){if(!window[n]||window[n].stub!==true){return}if(!a.data){return}
#     var i=typeof a.data==="string";var e;try{e=i?JSON.parse(a.data):a.data}catch(t){return}if(e[o]){var r=e[o];window[n](r.command,r.parameter,function(e,t){var n={};n[c]={returnValue:e,success:t,callId:r.callId};a.source.postMessage(i?JSON.stringify(n):n,"*")},r.version)}}
#     if(typeof window[n]!=="function"){window[n]=e;if(window.addEventListener){window.addEventListener("message",t,false)}else{window.attachEvent("onmessage",t)}}}e("__tcfapi","__tcfapiBuffer","__tcfapiCall","__tcfapiReturn");a("__tcfapiLocator");(function(e){
#     var t=document.createElement("script");t.id="spcloader";t.type="text/javascript";t.async=true;t.src="https://sdk.privacy-center.org/"+e+"/loader.js?target_type=notice&target=TtwHt2xD";t.charset="utf-8";var n=document.getElementsByTagName("script")[0];n.parentNode.insertBefore(t,n)})('e23a01f6-a508-4e71-8f50-c1a9cae7c0d0')})();</script>
# <!-- DIDOMI CMP SCRIPT ENDS -->
# <script type="text/javascript">
#     var dataLayerJan = {"site_route":"homepage"};
#         window.jan=window.jan||{},jan.cmd=jan.cmd||[],jancmd=function(){jan.cmd.push(arguments)};
#     </script>
# <script type="text/javascript">
#         var JadConfig = {"provider":"dfp","system":"jad","account-id":"\/120157152","account-first-level":"\/ALLOCINE_FR_WEB","tag-id":"\/120157152\/ALLOCINE_FR_WEB","tag-other-levels":"\/homepage\/home","navEgg":null,"targeting":{"site":"allocine","site_route":"homepage","site_section":"home","environment":"web","video_id":"20615817","video_movie_id":"313672"},"autoRefresh":true,"cmpPaywall":{"name":"didomi","siteId":"e23a01f6-a508-4e71-8f50-c1a9cae7c0d0","noticeId":"TtwHt2xD","paywall":{"clientId":"AVvF60FpOZcS6UoBe6sf8isBLYwzuLgMQCnNdE-FvpoW_OhR8P6zERqhyuIBGPOxqrTHKxv7QxsXnfck","planId":"P-66F73522PX986223DMBQZG5A","tosUrl":"\/service\/cgv.html","touUrl":"\/service\/conditions.html","privacyUrl":"\/service\/charte.html"},"includeCmp":false},"customInterstitialCapping":1,"adsMapping":{"interstitial":"dfp-interstitial","header":"dfp-masthead","inread1":"dfp-inread","rectangle_atf":"dfp-atf","rectangle_mtf":"dfp-mtf","rectangle_btf":"dfp-btf","rectangle_mtf_2":"dfp-autopromo","rectangle_atf_diapo":"dfp-slideshow","slideshow_native_banner":"dfp-slideshownativebanner","imagead":"dfp-imagead","header_link":"dfp-headerlink","footer":"dfp-footer","pulse":"dfp-pulse","native_banner":"dfp-nativebanner","native_banner_ope":"dfp-nativebanner-ope","native_button":"dfp-nativebutton","native_rectangle":"dfp-nativerectangle","native_VOD":"dfp-nativevod","native_booking":"dfp-nativebooking","inread_added":"dfp-added-ad"}};
#         var JadIds    = ["dfp-interstitial","dfp-headerlink","dfp-masthead","dfp-atf","dfp-footer","dfp-pulse"];
#         var WadsKeywords = {"route":"homepage","site":"allocine_fr","page":"home","mode":"async"};
#     </script>
# <script type="text/javascript">(function (win) {
#     win.AC = win.AC || {};
#     AC.config = {"releaseWeekDay":"Wednesday","locale":"fr_FR","lang":"fr","brand":"allocine","siteKey":"fr","graphCountryName":"FRANCE","display_provider":"jad","asset_version":"__GIT_COMMIT__","env":"prod","assetsUrls":{"css":{"secondary":"https:\/\/assets.allocine.fr\/skin\/css\/allocine\/secondary-styles.min.5a27fc87.css","font":"https:\/\/assets.allocine.fr\/skin\/css\/allocine\/font.min.7c570837.css"},"images":{"bronson":"https:\/\/assets.allocine.fr\/skin\/img\/userspace\/bronson.e492ec8e.gif","cineRelax":"https:\/\/assets.allocine.fr\/skin\/img\/logo-cine-relax.9ddea53f.svg","etoile":"https:\/\/assets.allocine.fr\/skin\/img\/etoiles.766780d2.png","ghostBuster":"https:\/\/assets.allocine.fr\/skin\/img\/userspace\/ghostbuster.7c731e13.png","logo":"https:\/\/assets.allocine.fr\/skin\/img\/logo-allocine.7e88ee87.svg","logoDark":"https:\/\/assets.allocine.fr\/skin\/img\/allocine\/logo-main-dark.536669e5.svg","macaron":"https:\/\/assets.allocine.fr\/skin\/img\/macaron.363298ee.png","notFound":"https:\/\/assets.allocine.fr\/skin\/img\/userspace\/not-found.dec1f46f.gif","onboarding":"https:\/\/assets.allocine.fr\/skin\/img\/allocine\/onboarding.a32c4541.png","rewind2024":"https:\/\/assets.allocine.fr\/skin\/img\/allocine\/rewind2024\/rewind-dark.d14607af.png","seriously":"https:\/\/assets.allocine.fr\/skin\/img\/seriously.ffccba64.gif","suggestions":"https:\/\/assets.allocine.fr\/skin\/img\/suggestions.0009180e.png","walle":"https:\/\/assets.allocine.fr\/skin\/img\/userspace\/walle.5d973cbb.png"}},"webedia_websites":["allocine.fr","www.academiedugout.fr","www.canalblog.com","www.over-blog.com","www.confidentielles.com","www.750g.com","www.alibabuy.com","www.chartsinfrance.net","www.dailyconso.com","www.easyvols.fr","www.easyvoyage.com","www.exponaute.com","www.forumjv.com","fr.ign.com","jeu.info","www.jeuxvideo.com","www.lebonguide.com","www.lofficielmode.com","www.millenium.org","www.purebreak.com","www.purecine.com","www.purefamille.com","www.purfans.com","www.pureloisirs.com","www.ozap.com","www.purepeople.com","www.puresaveurs.com","www.shopoon.fr","www.puresweethome.com","www.puretrend.com","www.terrafemina.com","www.yasmina.com","www.atyabtabkha.3a2ilati.com","www.3a2ilati.com","www.mashaheeri.com","www.mazyun.com","www.beyazperde.com","www.filmstarts.de","www.moviepilot.de","www.gamestar.de","www.onlinewelten.com","de.ign.com","www.gamespilot.de","www.heimgourmet.com","www.easyvoyage.de","www.adorocinema.com","br.ign.com","www.purepeople.com.br","www.purebreak.com.br","www.pureviagem.com.br","www.tudogostoso.com.br","www.receitas-sem-fronteiras.com","www.easyvoyage.co.uk","www.dealchecker.co.uk","www.gourmandize.com","www.sensacine.com","www.3djuegos.com","es.ign.com","www.easyviajar.com","www.rebanando.com","www.easyviaggio.com","www.tribugolosa.com"],"hosts":{"assets":"https:\/\/assets.allocine.fr","secure":"https:\/\/secure.allocine.fr","secureApi":"https:\/\/api-secure.allocine.fr","validation":"https:\/\/secure.allocine.fr","sso":"https:\/\/sso.allocine.fr","graph":"https:\/\/graph.allocine.fr","hostname":"allocine.fr"},"jan_config":{"src":"https:\/\/cdn.lib.getjan.io\/library\/allocine.js"},"ads":{"displayProvider":"jad","prerollProvider":"jad","postrollProvider":null,"postrollTrailerProvider":"jad","postrollProxy":"\/\/videos.allocine.fr","atf":"atf","slideshow":"slideshow","slideshownativebanner":"slideshownativebanner","positions":"dfp-atf,dfp-mtf,dfp-btf,dfp-interstitial,dfp-masthead,dfp-footer,dfp-slideshow,dfp-slideshownativebanner,dfp-sticky-amp,,,dfp-inread,,,,dfp-headerlink,,dfp-autopromo,dfp-pulse,dfp-nativebanner,dfp-nativebanner-ope,dfp-nativerectangle,dfp-nativebutton,dfp-nativevod,dfp-nativebooking,","nativebooking":"nativebooking"},"secureApiPartnerKey":"000042532791","facebook":{"appId":"99197768694","version":"v3.2","permissions":"public_profile email user_friends"},"google":{"appId":"472230823030.apps.googleusercontent.com","apiKey":"pxKT_spGOdGnt7MVJXcTGCGr","permissions":"https:\/\/www.googleap ...
#     AC.routing = {"base_url":"","routes":{"rewind_conf_json":{"tokens":[["text","\/_\/rewind_config.dd7c406038da4d5735d4f7bfad2eb0fa8927a26f.json"]],"defaults":{"_controller":"AppBundle\\Rewind\\Controller\\RewindConfController::rewindAction","_format":"json","options":{"expose":true},"_cache_control":{"enabled":true,"ttl":3600},"_universe":"default"},"requirements":[],"hosttokens":[],"methods":[],"schemes":[]},"fos_js_routing_js":{"tokens":[["variable",".","js|json","_format",true],["text","\/js\/routing"]],"defaults":{"_controller":"fos_js_routing.controller::indexAction","_format":"js","_cache_control":{"enabled":true,"ttl":3600},"_universe":"default"},"requirements":{"_format":"js|json"},"hosttokens":[],"methods":["GET"],"schemes":[]},"allocine__moviepage":{"tokens":[["text",".html"],["variable","=","[1-9]\\d*","movie",true],["text","\/film\/fichefilm_gen_cfilm"]],"defaults":{"_controller":"AppBundle\\Controller\\MoviePageController::indexAction","_api":[{"entity":"MOVIE","mainParam":"movie","description":"Homepage","params":{"movie":"MOVIE"}}],"_brand":"allocine","_cache_control":{"enabled":true,"ttl":3600},"_universe":"moviepage"},"requirements":{"movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"],"schemes":[]},"allocine__moviepage_showtimes":{"tokens":[["text","\/"],["variable","-","[1-9]\\d*","movie",true],["text","\/seance\/film"]],"defaults":{"_controller":"AppBundle\\Controller\\MoviePageController::showtimesAction","_api":[{"entity":"MOVIE","mainParam":"movie","description":"Showtimes","params":{"movie":"MOVIE"}}],"_brand":"allocine","_cache_control":{"enabled":true,"ttl":3600},"_universe":"moviepage"},"requirements":{"movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"],"schemes":[]},"allocine__moviepage_showtimes_place":{"tokens":[["text","\/"],["variable","-","\\d+","localization",true],["text","\/pres-de"],["variable","-","[1-9]\\d*","movie",true],["text","\/seance\/film"]],"defaults":{"_controller":"AppBundle\\Controller\\MoviePageController::showtimesPlaceAction","_brand":"allocine","_cache_control":{"enabled":true,"ttl":3600},"_universe":"moviepage"},"requirements":{"localization":"\\d+","movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"],"schemes":[]},"allocine__moviepage_showtimes_my_theaters":{"tokens":[["text","\/favoris\/seances\/"],["variable","-","[1-9]\\d*","movie",true],["text","\/seance\/film"]],"defaults":{"_controller":"AppBundle\\Controller\\MoviePageController::showtimesMyTheatersAction","_brand":"allocine","_cache_control":{"enabled":true,"ttl":3600},"_universe":"moviepage"},"requirements":{"movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"],"schemes":[]},"allocine__moviepage_showtimes_lookup":{"tokens":[["text","\/recherche\/"],["variable","-","[1-9]\\d*","movie",true],["text","\/seance\/film"]],"defaults":{"_controller":"AppBundle\\Controller\\MoviePageController::showtimesLookupAction","_brand":"allocine","_cache_control":{"enabled":true,"ttl":3600},"_universe":"moviepage"},"requirements":{"movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"],"schemes":[]},"allocine__moviepage_videos_trailer":{"tokens":[["text",".html"],["variable","=","[1-9]\\d*","movie",true],["text","&cfilm"],["variable","=","[1-9]\\d*","idMedia",true],["text","\/video\/player_gen_cmedia"]],"defaults":{"_controller":"AppBundle\\Controller\\MoviePageController::videosTrailerAction","_brand":"allocine","_cache_control":{"enabled":true,"ttl":3600},"_universe":"moviepage"},"requirements":{"idMedia":"[1-9]\\d*","movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"],"schemes":[]},"allocine__moviepage_all_videos_trailer":{"tokens":[["text","\/toutes\/"],["variable","-","[1-9]\\d*","movie",true],["text","\/videos\/fichefilm"]],"defaults":{"_controller":"AppBundle\\Controller\\MoviePageController::allVideosTrailerAction","_brand":"allocine","_cache_control":{"enable ...
#     AC.route = 'homepage';
# }(window));
# </script>
# <script src="https://assets.allocine.fr/js/website/translations-3c2c9b3a976e5b6a646dc67d14f21fd0.fr_FR.js"></script>
# <script src="https://assets.allocine.fr/js/website/website-common.e461f236e0f6bb5d45c6.js" type="text/javascript"></script>
# <script defer="" src="https://assets.allocine.fr/js/website/home.8d4f93104b57ac4a55be.js" type="text/javascript"></script>
# <script type="text/javascript">
#     var dataLayer = dataLayer || [{"site_route":"home","site_section":"other"}];
# </script>
# <noscript>
# <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-PL6PBF" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <script type="text/javascript">
#             var asyncDataLayers = [];
#             var jsEntities = [];
#         </script>
# <script>
#     (function(win, undefined) {
#         var tests = [];
#
#         // add tests here
#         tests.push(function() {
#             return 'CSS' in win && CSS.supports('display', 'grid');
#         });
#
#         // run all tests
#         var length = tests.length;
#         var idx = 0;
#         var supported = true;
#
#         for (idx = 0; supported && idx < length; idx += 1) {
#             supported = tests[idx]();
#         }
#
#         // display banner
#         if (!supported) {
#             var doc = win.document;
#             var alertBanner = doc.createElement('div');
#             var alertContent = alertBanner.cloneNode('div'); // performence best pratice
#             var bannerText = doc.createTextNode("La version de votre navigateur n'est plus supportée, l'expérience sur le site sera dégradée. Si vous ne pouvez ni mettre à jour votre navigateur, ni en changer, sachez que le site est consultable sur mobile à la même adresse.");
#
#             alertBanner.className = "alert-deprecated-banner alert-info";
#             alertContent.className = "alert-content";
#
#             var body = doc.body;
#             var head = doc.getElementsByTagName('head')[0];
#
#             var header = doc.getElementById('main-header');
#             var link = doc.createElement('link');
#
#             alertContent.appendChild(bannerText);
#             alertBanner.appendChild(alertContent);
#
#             body.insertBefore(alertBanner, header || body.firstChild);
#             body.className += ' deprecated';
#
#             // @todo css deprecated
#             link.setAttribute('href', 'https\u003A\/\/assets.allocine.fr\/skin\/css\/allocine\/deprecated.min.73cbaa92.css');
#             link.setAttribute('rel', 'stylesheet');
#             link.setAttribute('type', 'text/css');
#             head.appendChild(link);
#         }
#     })(window);
# </script>
# </div>
# </body>

# %% [markdown]
# On your web browser (Chrome, Firefox,...), you can use the "inspect" function (right click -> inspect) and drag your mouse to the areas of the page that interest you. At the same time you will see the part of the HTML script highlighted that corresponds to the area that interests you.
#
# That's how you find the tags that you are interested in.

# %% [markdown]
# I notice that the relative link of the web page specific to the new movie on the poster is stored in these tags:
#
# ```html
# <a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=235582.html" title="Le Grand Bain">Le Grand Bain</a>
# ```

# %%
for p in soup.find_all("a"):
    print(p.text)
# Out:
# Meilleurs films d'animation Disney
# Meilleurs films Pixar
#
#             Cinéma
#
#
#             Séries
#
#
#             Streaming
#
#
#             Trailers
#
#
#             VOD
#
#
#             Les indés
#
# séances cinéma
# news
# dossiers
# émissions AlloCiné
# dernières bandes-annonces
# Agenda des sorties
# Kids
# Meilleurs films
# Meilleurs documentaires
# Avant-premières
# Box Office
# Films pour enfants à l'affiche
# DVD
# Meilleurs films 2019
# Tous les films pour enfants
# Tous les films
# Sorties de la semaine
# Minecraft, Le Film
# Le Routard
# Ozi, la voix de la forêt
# Natacha (presque) hôtesse de l’air
# Shaka Ponk – The final fucked up tour - Le final au cinéma
# Lads
# Deux sœurs
# Cassandre
# Nous voilà grands !
# Au pays de nos frères
# Ma Mère, Dieu et Sylvie Vartan
# Blanche Neige
# On Ira
# Les Bodin’s partent en vrille
# Tous les films encore à l'affiche
#  Piégé
#  Zion
#  Moon le panda
#  Rapide
#  La Réparation
# Tous les films à venir
# Dernières news cinéma
# C'est l'un des plus grands films d'animation de ces 15 dernières années et il est de retour en prises de vues réelles : découvrez la nouvelle bande-annonce de Dragons
# Ce soir à la télé : ni Incassable, ni Sixième Sens, ce thriller reste l'un des meilleurs films de Shyamalan
# Jurassic Park : pendant 32 ans, personne n'a jamais vraiment fait attention à ce personnage, et pourtant ce n'est pas n'importe qui
# Quiz Cinéma : tente de reconnaître ces 10 films avec une seule image !
# Il y a 19 ans, en pleine interview pour son nouveau film, ce légendaire réalisateur s'est fait tirer dessus !
# 15 ans après, ce film Disney noté 4,2 sur 5 pourrait faire son retour au cinéma avec une star planétaire
# Tous les dossiers cinéma
# Bandes-annonces à ne pas manquer
# Dragons
# Dragons Bande-annonce (2) VF
# Piégé Bande-annonce VO STFR
# Ma Mère, Dieu et Sylvie Vartan Bande-annonce VF
# Croix de fer Bande-annonce VO
# John Carter Extrait vidéo VO
# Disney+
# Netflix
# Crunchyroll
# Amazon Prime Video
# Canal+
# TF1+
# Max
# Vous avez aimé The Big Bang Theory et Young Sheldon ? Alors cette nouvelle série est faite pour vous !
# Netflix a attendu 18 ans pour explorer ce genre très populaire et on ne comprend pas pourquoi ils ne l’ont pas fait avant
# House of the Dragon saison 3 : le tournage débute avec de nouveaux noms au casting !
# "Des émotions très fortes jusqu'au dernier plan" : noté 4,1 sur 5, c'est le meilleur film d’Amanda Seyfried !
# Séries à voir  sur CANAL+
# Dexter : Les Origines
# Dope Girls
# Marie Antoinette : L’Affaire du collier
# Marie Antoinette
# Le Bureau des Légendes
# Meilleures séries  sur Netflix
# Breaking Bad
# Arcane
# Notre planète
# Peaky Blinders
# 1883
# Films disponibles  sur Disney+
# Une zone à défendre
# Star Wars : Episode III - La Revanche des Sith
# Le Crime de l'Orient-Express
# Le Village
# Il était une fois en Amérique
# Films disponibles sur Prime Video
# Carjackers
# Holland
# L'amour dans l'objectif
# Marked Men: Rule & Shaw
# The Order
# Les derniers films en VOD
# Gladiator II
# Vaiana 2
# Fotogenico
# Les dernières séries en VOD
# Flashback
# The Walking Dead : Dead City
# Wolf Like Me
# Meilleures séries
# Séries tv inédites à voir
# Nouvelles saisons attendues
# Toutes les séries
# Dernières vidéos de séries
# Toutes les vidéos de séries
# Tous les teasers de séries
# Top séries de la semaine
# Adolescence
# Kaboul
# The White Lotus
# Faute de preuves
# Les séries les plus attendues
# Clean
# Ghosts : Fantômes en héritage
# Carême
# Alien: Earth
# L'actu séries
# 37 Secondes sur Arte : faut-il regarder ce thriller captivant inspiré d'une histoire vraie ?
# Flashback sur TF1 : que vaut cette série policière avec Michael Youn ?
# Plus belle la vie en avance : ce qui vous attend dans l'épisode 304 du vendredi 4 avril 2025 [SPOILERS]
# TVActu
# “On va remettre le couvert à la fin de l’été”, un couple de Mariés au premier regard prépare l’arrivée de bébé 2 !
# Rebondissement, Laurent Maistret change les règles en pleine épreuve ! Ce qui vous attend dans Les apprentis aventuriers ce mardi 1er avril
# Familles nombreuses : "On apprend juste à vivre avec", Emilie Fanich adresse un message lourd de sens
# “Deux doigts coupés”, qu’est-il arrivé à Olivier Gayat de Familles nombreuses ?
# Exclu. Les Traîtres : une anecdote improbable va bouleverser les candidats ! “On en parle encore”
# “Je sens qu’il y a un truc qui va pas”, Guillaume va-t-il dire oui à Sophie ? On a vu le prochain épisode de Mariés au premier regard
# Top Chef : qui a été éliminé dans l’émission du mercredi 2 avril 2025 ?
# "J’ai autre chose à faire que de regarder ça. C’est ignoble !", un ex juge cash sur ce qui a changé dans Top Chef
# News émissions TV
# News téléréalité
# Faux raccord
# Grand Écran
# PILS - Par Ici Les Sorties
# Voix Ouf
# Aviez-vous remarqué ?
# Fanzone
# Ma scène préférée
# Stars
# Interviews
# Anniversaires
# Toutes les stars
# Toutes les stars françaises
# Toutes les stars américaines
# Top stars complet
# Bandes originales
# Musique de films
# Musique de séries TV
# OCS
# News jeux vidéo
# Mobilité Verte
# Filmstarts
# Beyazperde
# SensaCine España
# SensaCine México
# SensaCine Colombia
# Adorocinema
# Préférences cookies
#
# Back to Top

# %% [markdown]
# This time, the site is more difficult to "extract". Let's use much more specific parameters to the search function `find_all`.

# %%
# In addition to the tag `a`, which is easily identifiable, we notice some additional
# information such as the value of the class variable of these identical tags.
for elem in soup.find_all("a", attrs={"class": "meta-title meta-title-link"}):
    print(elem)
# Out:
# <a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=227463.html" title="Minecraft, Le Film">Minecraft, Le Film</a>
# <a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=321603.html" title="Le Routard">Le Routard</a>
# <a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=294847.html" title="Ozi, la voix de la forêt">Ozi, la voix de la forêt</a>
# <a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=259157.html" title="Natacha (presque) hôtesse de l’air">Natacha (presque) hôtesse de l’air</a>
# <a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=1000016160.html" title="Shaka Ponk – The final fucked up tour - Le final au cinéma">Shaka Ponk – The final fucked up tour - Le final au cinéma</a>
# <a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=310111.html" title="Lads">Lads</a>
# <a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=316235.html" title="Deux sœurs">Deux sœurs</a>
# <a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=318265.html" title="Cassandre">Cassandre</a>
# <a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=1000019618.html" title="Nous voilà grands !">Nous voilà grands !</a>
# <a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=325171.html" title="Au pays de nos frères">Au pays de nos frères</a>
# <a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=316984.html" title="Ma Mère, Dieu et Sylvie Vartan">Ma Mère, Dieu et Sylvie Vartan</a>
# <a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=251421.html" title="Blanche Neige">Blanche Neige</a>
# <a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=289215.html" title="On Ira">On Ira</a>
# <a class="meta-title meta-title-link" href="/film/fichefilm_gen_cfilm=326019.html" title="Les Bodin’s partent en vrille">Les Bodin’s partent en vrille</a>
# <a class="meta-title meta-title-link" href="/series/ficheserie_gen_cserie=36351.html" title="Adolescence">Adolescence</a>
# <a class="meta-title meta-title-link" href="/series/ficheserie_gen_cserie=30856.html" title="Kaboul">Kaboul</a>
# <a class="meta-title meta-title-link" href="/series/ficheserie_gen_cserie=27480.html" title="The White Lotus">The White Lotus</a>
# <a class="meta-title meta-title-link" href="/series/ficheserie_gen_cserie=1000000134.html" title="Faute de preuves">Faute de preuves</a>
# <a class="meta-title meta-title-link" href="/series/ficheserie_gen_cserie=36595.html" title="Clean">Clean</a>
# <a class="meta-title meta-title-link" href="/series/ficheserie_gen_cserie=36875.html" title="Ghosts : Fantômes en héritage">Ghosts : Fantômes en héritage</a>
# <a class="meta-title meta-title-link" href="/series/ficheserie_gen_cserie=34670.html" title="Carême">Carême</a>
# <a class="meta-title meta-title-link" href="/series/ficheserie_gen_cserie=27910.html" title="Alien: Earth">Alien: Earth</a>

# %% [markdown]
# #### Recovery of `href`

# %% [markdown]
# We have noticed the presence of `href` links to the pages that interest us. Let's go get them back:

# %%
for elem in soup.find_all("a", attrs={"class": "meta-title meta-title-link"}):
    print(elem.get("href"))
# Out:
# /film/fichefilm_gen_cfilm=227463.html
# /film/fichefilm_gen_cfilm=321603.html
# /film/fichefilm_gen_cfilm=294847.html
# /film/fichefilm_gen_cfilm=259157.html
# /film/fichefilm_gen_cfilm=1000016160.html
# /film/fichefilm_gen_cfilm=310111.html
# /film/fichefilm_gen_cfilm=316235.html
# /film/fichefilm_gen_cfilm=318265.html
# /film/fichefilm_gen_cfilm=1000019618.html
# /film/fichefilm_gen_cfilm=325171.html
# /film/fichefilm_gen_cfilm=316984.html
# /film/fichefilm_gen_cfilm=251421.html
# /film/fichefilm_gen_cfilm=289215.html
# /film/fichefilm_gen_cfilm=326019.html
# /series/ficheserie_gen_cserie=36351.html
# /series/ficheserie_gen_cserie=30856.html
# /series/ficheserie_gen_cserie=27480.html
# /series/ficheserie_gen_cserie=1000000134.html
# /series/ficheserie_gen_cserie=36595.html
# /series/ficheserie_gen_cserie=36875.html
# /series/ficheserie_gen_cserie=34670.html
# /series/ficheserie_gen_cserie=27910.html

# %% [markdown]
# Can you retrieve the titles for me by searching for `"title"` in the items of the previous list?

# %%
for title in soup.find_all("a", attrs={"class": "meta-title meta-title-link"}):
    print(title.get("title"))
# Out:
# Minecraft, Le Film
# Le Routard
# Ozi, la voix de la forêt
# Natacha (presque) hôtesse de l’air
# Shaka Ponk – The final fucked up tour - Le final au cinéma
# Lads
# Deux sœurs
# Cassandre
# Nous voilà grands !
# Au pays de nos frères
# Ma Mère, Dieu et Sylvie Vartan
# Blanche Neige
# On Ira
# Les Bodin’s partent en vrille
# Adolescence
# Kaboul
# The White Lotus
# Faute de preuves
# Clean
# Ghosts : Fantômes en héritage
# Carême
# Alien: Earth

# %% [markdown]
# #### Get summary

# %% [markdown]
# Let's start by building the URL that we will use to retrieve the summaries.
#
# Start by putting the `href` values in a list of links.

# %%
links = []
for elem in soup.find_all("a", attrs={"class": "meta-title meta-title-link"}):
    links.append(elem.get("href"))
links
# Out:
# ['/film/fichefilm_gen_cfilm=227463.html',
#  '/film/fichefilm_gen_cfilm=321603.html',
#  '/film/fichefilm_gen_cfilm=294847.html',
#  '/film/fichefilm_gen_cfilm=259157.html',
#  '/film/fichefilm_gen_cfilm=1000016160.html',
#  '/film/fichefilm_gen_cfilm=310111.html',
#  '/film/fichefilm_gen_cfilm=316235.html',
#  '/film/fichefilm_gen_cfilm=318265.html',
#  '/film/fichefilm_gen_cfilm=1000019618.html',
#  '/film/fichefilm_gen_cfilm=325171.html',
#  '/film/fichefilm_gen_cfilm=316984.html',
#  '/film/fichefilm_gen_cfilm=251421.html',
#  '/film/fichefilm_gen_cfilm=289215.html',
#  '/film/fichefilm_gen_cfilm=326019.html',
#  '/series/ficheserie_gen_cserie=36351.html',
#  '/series/ficheserie_gen_cserie=30856.html',
#  '/series/ficheserie_gen_cserie=27480.html',
#  '/series/ficheserie_gen_cserie=1000000134.html',
#  '/series/ficheserie_gen_cserie=36595.html',
#  '/series/ficheserie_gen_cserie=36875.html',
#  '/series/ficheserie_gen_cserie=34670.html',
#  '/series/ficheserie_gen_cserie=27910.html']

# %% [markdown]
# The absolute URL of the movie pages we are looking for are built in this form: http://www.allocine.fr/film/fichefilm_gen_cfilm=243835.html
#
# It is therefore necessary to take the previous list and build the absolute URLs for our search
# It's up to you to play.
#
# NB: Do not take the links for the shows(series). We only want movies.

# %%
movie_links = ["http://www.allocine.fr" + elem for elem in links if "film" in elem]
movie_links
# Out:
# ['http://www.allocine.fr/film/fichefilm_gen_cfilm=227463.html',
#  'http://www.allocine.fr/film/fichefilm_gen_cfilm=321603.html',
#  'http://www.allocine.fr/film/fichefilm_gen_cfilm=294847.html',
#  'http://www.allocine.fr/film/fichefilm_gen_cfilm=259157.html',
#  'http://www.allocine.fr/film/fichefilm_gen_cfilm=1000016160.html',
#  'http://www.allocine.fr/film/fichefilm_gen_cfilm=310111.html',
#  'http://www.allocine.fr/film/fichefilm_gen_cfilm=316235.html',
#  'http://www.allocine.fr/film/fichefilm_gen_cfilm=318265.html',
#  'http://www.allocine.fr/film/fichefilm_gen_cfilm=1000019618.html',
#  'http://www.allocine.fr/film/fichefilm_gen_cfilm=325171.html',
#  'http://www.allocine.fr/film/fichefilm_gen_cfilm=316984.html',
#  'http://www.allocine.fr/film/fichefilm_gen_cfilm=251421.html',
#  'http://www.allocine.fr/film/fichefilm_gen_cfilm=289215.html',
#  'http://www.allocine.fr/film/fichefilm_gen_cfilm=326019.html']

# %% [markdown]
# Finally, on each page, the title and synopsis must be retrieved. Let's try for a movie, the first of the list.

# %%
url = movie_links[0]
r = requests.get(url)
print(url, r.status_code)
soup = BeautifulSoup(r.content, "html")
soup = soup.find("body")
soup
# Out:
# http://www.allocine.fr/film/fichefilm_gen_cfilm=227463.html 200
# <body class="allocine allocine__moviepage logged-out" data-migration="graph" id="allocine__moviepage">
# <div class="sub-body">
# <div class="js-interstitial ad-interstitial ad-item" id="dfp-interstitial"></div>
# <header class="header-main" id="header-main" role="banner">
# <div class="header-main-center">
# <div class="header-main-top">
# <div aria-label="Bouton Menu mobile" class="header-main-btn-mobile icon icon-hamburger" id="header-main-mobile-btn-menu"></div>
# <div class="header-main-logo-holder">
# <span class="ACrLw=ACr= header-main-logo">
# <img alt="allocine" class="header-main-logo-img" height="37" src="https://assets.allocine.fr/skin/img/allocine/logo-main.ab1b33da.svg" width="162"/>
# <span class="header-main-logo-name">AlloCiné</span>
# </span>
# </div>
# <form action="/rechercher/" aria-label="formulaire de recherche principal du site" class="header-main-search" id="search-header" method="get" role="form">
# <fieldset class="header-main-search-fieldset" id="search-engine">
# <div class="header-search-form-container"><input class="header-search-input" id="header-search-input" name="site_search[q]" placeholder="Rechercher un film, une série, une star..." type="text"/><button aria-label="Envoyer" class="header-search-submit icon icon-search" title="Rechercher" type="submit"></button></div> </fieldset>
# <div class="header-main-search-mobile-layer" id="header-main-search-mobile-layer"></div>
# </form>
# <div class="header-ads-zone">
# <div class="js-headerlink ad-headerlink ad-item" id="dfp-headerlink"></div>
# </div>
# <div aria-label="Bouton Rechercher" class="header-main-btn-mobile icon icon-search" id="header-main-mobile-btn-search"></div>
# <div class="header-main-btn-mobile header-main-mobile-btn-userspace" id="header-main-mobile-btn-userspace">
# <span aria-label="Bouton Mon compte" class="icon icon-profil"></span>
# <img alt="" class="avatar js-myaccount-avatar" src="..."/>
# </div>
# </div>
# <div class="header-main-bottom">
# <nav aria-label="Menu principal du site" class="header-main-nav" id="header-main-nav" role="navigation"><ul class="header-nav-holder"><li class="header-nav-item"><span class="ACrL25ACrld3Mv header-nav-link" title="News">
#             News
#         </span></li><li class="header-nav-item is-active"><span class="ACrL2ZACrpbG0v header-nav-link current" title="Cinéma">
#             Cinéma
#         </span><div class="header-main-subnav-holder"><ul class="header-main-subnav"><li class="header-subnav-item"><span class="ACrL2ZACrpbG0vbWVpbGxldXJzLw== header-nav-link" title="Meilleurs films">
#             Meilleurs films
#         </span></li><li class="header-subnav-item"><span class="ACrL2ZACrpbG0vYXVjaW5lbWEv header-nav-link" title="Films à l'affiche">
#             Films à l'affiche
#         </span></li><li class="header-subnav-item"><span class="ACrL2ZACrpbG0vYXR0ZW5kdXMv header-nav-link" title="Prochainement">
#             Prochainement
#         </span></li><li class="header-subnav-item"><span class="ACrL3NACrhbGxlLw== header-nav-link" title="Séances">
#             Séances
#         </span></li><li class="header-subnav-item"><span class="ACrL2tACrpZHMv header-nav-link" data-jan='{"eventAction":"click","eventName":"internal","position_name":"kids_menu","filters_value":"https:\/\/www.allocine.fr\/film\/fichefilm_gen_cfilm=227463.html"}' title="Kids">
#                         Kids
#                     </span></li><li class="header-subnav-item"><span class="ACrL2JACrveG9mZmljZS9mcmFuY2Uv header-nav-link" title="Box Office">
#             Box Office
#         </span></li><li class="header-subnav-item"><span class="ACrL2ZACrpbG0vY291cnQtbWV0cmFnZS8= header-nav-link" title="Courts-métrages">
#             Courts-métrages
#         </span></li><li class="header-subnav-item"><span class="ACrL2RACr2ZC8= header-nav-link" title="DVD">
#             DVD
#         </span></li><li class="header-subnav-item"><span class="ACrL2ZACrpbG1zLw== header-nav-link" title="Tous les films">
#             Tous les films
#         </span></li></ul></div></li><li class="header-nav-item"><span class="ACrL3NACrlcmllcy8= header-nav-link" title="Séries">
#             Séries
#         </span></li><li class="header-nav-item"><span class="ACrL3NACr0cmVhbWluZy8= header-nav-link" data-jan='{"eventAction":"click","eventName":"internal","position_name":"navigation_menu_click","filters_value":"https:\/\/www.allocine.fr\/film\/fichefilm_gen_cfilm=227463.html"}' title="Streaming">
#             Streaming
#         </span></li><li class="header-nav-item"><span class="ACrL3RACr2YWN0dS8= header-nav-link" title="TVActu">
#             TVActu
#         </span></li><li class="header-nav-item"><span class="ACrL3RACryYWlsZXIv header-nav-link" title="Trailers">
#             Trailers
#         </span></li><li class="header-nav-item"><span class="ACrL3ZACrvZC8= header-nav-link" title="VOD">
#             VOD
#         </span></li><li class="header-nav-item"><span class="ACrL2ZACrpbG0vbGVzaW5kZXMv header-nav-link" title="Les indés">
#             Les indés
#         </span></li><li class="header-nav-item"><span class="ACrL21ACr5Y2FuYWwv header-nav-link" title="Canal+">
#             Canal+
#         </span></li></ul></nav><div class="header-userspace-nav" id="header-userspace-nav"><span aria-label="Bouton Mon compte" class="ACrLy9ACrtb24uYWxsb2NpbmUuZnIv header-nav-userspace-upper-link"><img alt="" class="avatar js-myaccount-avatar" src="..."/>
#                     Mon compte
#                 </span><div class="header-nav-userspace-holder"><div class="header-nav-userspace-sso"><span class="ACrLy9ACrtb24uYWxsb2NpbmUuZnIvY29ubmV4aW9uLz9yZXR1cm5Vcmw9aHR0cHMlM0ElMkYlMkZ3d3cuYWxsb2NpbmUuZnIlMkZmaWxtJTJGZmljaGVmaWxtX2dlbl9jZmlsbSUzRDIyNzQ2My5odG1s button button-social-ac-ghost button-sm sign-in"><span class="txt">Identifiez-vous</span></span><span class="ACrLy9ACrtb24uYWxsb2NpbmUuZnIvaW5zY3JpcHRpb24vP3JldHVyblVybD0lMkYlMkZtb24uYWxsb2NpbmUuZnIlMkY= button button-social-ac-full button-sm sign-up"><span class="txt">Créez votre compte</span></span></div><ul class="header-nav-userspace-subcontent"></ul></div></div> </div>
# </div>
# </header>
# <div class="main-banner">
# <div class="js-masthead ad-masthead ad-item" id="dfp-masthead"></div>
# </div>
# <main class="content-layout entity movie cf seance-geoloc-redir" data-seance-geoloc-redir="227463" id="content-layout" role="main">
# <div class="section-wrap breadcrumb">
# <a class="item" href="/">Accueil</a><a class="item" href="/film/">Cinéma</a><a class="item" href="/film/aucinema/">Films à l'affiche</a><h1 class="item">
#     Minecraft, Le Film de Jared Hess    </h1></div>
# <div class="titlebar titlebar-page"><div class="titlebar-title titlebar-title-xl">Minecraft, Le Film</div><div class="titlebar-action-holder affinity"><div class="js-affinity-badge" data-entity-id="TW92aWU6MjI3NDYz"></div></div></div>
# <nav aria-label="Navigation de la page Film" class="entity-page-nav" role="navigation">
# <div class="roller-holder js-roller roller-arrow-title roller-entity-page-menu" data-offset="20"><div class="roller-overflow"><div class="roller-slider"><span class="home roller-item current" href="/film/fichefilm_gen_cfilm=227463.html" title="Accueil"><div class="item-center">Accueil</div></span><a class="seance roller-item" href="/seance/film-227463/" id="js-showtimes-nav-redir" title="Séances"><div class="item-center">Séances</div></a><span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTIyNzQ2My9hY3R1Lw== roller-item" title="News"><div class="item-center">News</div></span><a class="trailer roller-item" href="/video/player_gen_cmedia=20617105&amp;cfilm=227463.html" title="Bandes-annonces"><div class="item-center">Bandes-annonces</div></a><span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTIyNzQ2My9jYXN0aW5nLw== roller-item" title="Casting"><div class="item-center">Casting</div></span><span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTIyNzQ2My9jcml0aXF1ZXMvc3BlY3RhdGV1cnMv roller-item" title="Critiques spectateurs"><div class="item-center">Critiques spectateurs</div></span><span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTIyNzQ2My9jcml0aXF1ZXMvcHJlc3NlLw== roller-item" title="Critiques presse"><div class="item-center">Critiques presse</div></span><span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTIyNzQ2My9waG90b3Mv roller-item" title="Photos"><div class="item-center">Photos</div></span><a class="roller-item" href="/film/fichefilm-227463/secrets-tournage/" title="Secrets de tournage"><div class="item-center">Secrets de tournage</div></a><a class="roller-item" href="/film/fichefilm-227463/similaire/" title="Films similaires"><div class="item-center">Films similaires</div></a></div></div><div class="roller-btn-holder"><button aria-label="Bouton aller vers la gauche" class="roller-btn btn-left icon icon-arrow-left disabled"></button><button aria-label="Bouton aller vers la droite" class="roller-btn btn-right icon icon-arrow-right"></button></div></div> </nav>
# <section class="section section-wrap gd-2-cols gd-gap-30">
# <div class="gd-col-left">
# <div class="js-nativebanner ad-nativebanner ad-item" id="dfp-nativebanner"></div>
# <div class="video-card-player">
# <figure class="player player-auto-play js-player" data-model='{"videos":[{"id":20617105,"idDailymotion":"x9fcke6","sources":{"highest":"https:\/\/fr.vid.web.acsta.net\/nmedia\/33\/25\/02\/28\/10\/26\/20617105_fhd_013.mp4","high":"https:\/\/fr.vid.web.acsta.net\/nmedia\/33\/25\/02\/28\/10\/26\/20617105_hd_013.mp4","standard":"https:\/\/fr.vid.web.acsta.net\/nmedia\/33\/25\/02\/28\/10\/26\/20617105_sd_013.mp4"},"image":"\/img\/7d\/4c\/7d4c9d433cc23f6bc5bec9d1b2a3902c.jpg","title":"Minecraft, Le Film Bande-annonce VF","trackingIdentifier":"20617105-minecraft_le_film_bande_annonce_vf","embedUrl":"ACraHRACr0cHM6Ly9wbGF5ZXIuYWxsb2NpbmUuZnIvMjA2MTcxMDUuaHRtbA==","file_type":"TRAILER","description":"Minecraft, Le Film Bande-annonce VF","duration":148,"view_count":50381,"added_at":{"date":"2025-02-28 10:21:18.000000","timezone_type":3,"timezone":"Europe\/Paris"},"metas":{"id_main_show":null,"name_main_show":null,"image_main_show":null,"id_main_movie":227463,"name_main_movie":"Minecraft, Le Film","image_main_movie":"\/img\/3e\/61\/3e619c6423fd2c82be9ec8b727aa217b.jpg","main_movie_videos":null,"id_main_series":null,"name_main_series":null,"image_main_series":null,"id_main_season":null,"name_main_season":null,"image_main_season":null,"main_season_number":null,"id_main_person":null,"name_main_person":null,"image_main_person":null,"use_portal":null,"release_date_main_movie":null,"nb_days_release_main_movie":null,"id_meta_category":null,"name_meta_category":null,"localized_file_type":null,"trans_file_type":null,"main_movie_type":null,"main_season_rating":null,"main_series_rating":null,"main_season_user_note_count":null,"genre_main_movie":null,"genre_main_series":null,"release_status_movie":null,"release_status_series":null},"stats":{"metric":{"starts":50381}},"is_emergence_inhibited":false,"publication":{"__typename":"Publication","startsAt":{"date":"2025-02-28 10:21:18.000000","timezone_type":3,"timezone":"Europe\/Paris"}},"relatedEntityType":"movie","relatedEntityId":227463,"relatedEntityTitle":"Minecraft, Le Film","relatedEntityUrl":"https:\/\/www.allocine.fr\/film\/fichefilm_gen_cfilm=227463.html","mediaUrl":"ACraHRACr0cHM6Ly93d3cuYWxsb2NpbmUuZnIvdmlkZW8vcGxheWVyX2dlbl9jbWVkaWE9MjA2MTcxMDUmY2ZpbG09MjI3NDYzLmh0bWw=","relatedEntityTrackingIdentifier":"227463-minecraft_le_film","genres":["ADVENTURE","COMEDY","FAMILY"],"countries":[{"id":5002,"name":"USA","localizedName":"U.S.A."}],"genresIds":[13001,13005,13036],"relatedEntityDistributor":"Warner Bros. France","relatedEntityDistributorId":929,"entityStatus":"in_theaters_reshowing"}],"disablePreroll":null,"disablePostroll":null,"endScreen":true,"context":"movie_page_ovw","launch":"auto-play","followScroll":true,"expandPlayer":true,"disableAutoPause":true}' data-player-dm-id="x1hyz" data-thumb="https://fr.web.img6.acsta.net/r_640_360/img/7d/4c/7d4c9d433cc23f6bc5bec9d1b2a3902c.jpg">
# <div class="media-holder js-media-holder">
# <div class="media-player-holder">
# <div class="js-media-player"></div>
# </div>
# </div>
# </figure>
# </div>
# <div class="card entity-card entity-card-list cf entity-card-player-ovw">
# <figure class="thumbnail">
# <span class="ACrL3ZACrpZGVvL3BsYXllcl9nZW5fY21lZGlhPTIwNjE3MTA1JmNmaWxtPTIyNzQ2My5odG1s thumbnail-container thumbnail-link" title="Bande-annonce Minecraft, Le Film">
# <img alt="poster du film Bande-annonce Minecraft, Le Film" class="thumbnail-img" height="420" src="https://fr.web.img3.acsta.net/c_310_420/img/3e/61/3e619c6423fd2c82be9ec8b727aa217b.jpg" width="310"/>
# </span>
# </figure>
# <div class="meta">
# <div class="meta-body">
# <div class="meta-body-item meta-body-info">
# <span class="ACrL2ZACrpbG0vYWdlbmRhL3NlbS0yMDI1LTA0LTAyLw== date blue-link">
#                     2 avril 2025
#                 </span>
# <span class="meta-release-type">
#             en salle
#
#
#
#
#     </span>
# <span class="spacer">|</span>
#
#
#                                             1h 41min
#
#                                             <span class="spacer">|</span>
# <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDAxLw== dark-grey-link">Aventure</span>,
#
#                                                                                 <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDA1Lw== dark-grey-link">Comédie</span>,
#
#                                                                                 <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDM2Lw== dark-grey-link">Famille</span>
# </div>
# <div class="meta-body-item meta-body-direction meta-body-oneline">
# <span class="light">De</span>
# <span class="ACrL3BACrlcnNvbm5lL2ZpY2hlcGVyc29ubmVfZ2VuX2NwZXJzb25uZT05NzYwMS5odG1s dark-grey-link">Jared Hess</span>
# </div>
# <span class="spacer">|</span>
# <div class="meta-body-item meta-body-direction meta-body-oneline">
# <span class="light">Par</span>
# <span class="ACrL3BACrlcnNvbm5lL2ZpY2hlcGVyc29ubmVfZ2VuX2NwZXJzb25uZT00MjI1Mi5odG1s dark-grey-link">Peter Sollett</span>,
#
#                                             <span class="ACrL3BACrlcnNvbm5lL2ZpY2hlcGVyc29ubmVfZ2VuX2NwZXJzb25uZT00MTQ0OTEuaHRtbA== dark-grey-link">Allison Schroeder</span>
# </div>
# <div class="meta-body-item meta-body-actor">
# <span class="light">Avec</span>
# <span class="ACrL3BACrlcnNvbm5lL2ZpY2hlcGVyc29ubmVfZ2VuX2NwZXJzb25uZT0yMTk3MS5odG1s dark-grey-link">Jack Black</span>,
#
#
#
#                                             <span class="ACrL3BACrlcnNvbm5lL2ZpY2hlcGVyc29ubmVfZ2VuX2NwZXJzb25uZT0xMDUxMjcuaHRtbA== dark-grey-link">Jason Momoa</span>,
#
#
#
#                                             <span class="ACrL3BACrlcnNvbm5lL2ZpY2hlcGVyc29ubmVfZ2VuX2NwZXJzb25uZT02NDk5NjQuaHRtbA== dark-grey-link">Danielle Brooks</span>
# </div>
# <div class="meta-body-item">
# <span class="light">Titre original </span>
# <span class="dark-grey">A Minecraft Movie</span>
# </div>
# </div>
# </div>
# <div class="label-holder">
# <div class="label kids-label aged-default">à partir de 6 ans</div>
# </div>
# <div class="rating-holder rating-holder-3">
# <div class="rating-item">
# <div class="rating-item-content">
# <span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTIyNzQ2My9jcml0aXF1ZXMvcHJlc3NlLw== rating-title"> Presse </span>
# <div class="stareval stareval-small stareval-theme-default"><div class="rating-mdl n20 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">2,0</span><span class="stareval-review light"> 10 critiques</span></div>
# </div>
# </div>
# <div class="rating-item">
# <div class="rating-item-content">
# <span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTIyNzQ2My9jcml0aXF1ZXMvc3BlY3RhdGV1cnMv rating-title"> Spectateurs </span>
# <div class="stareval stareval-small stareval-theme-default"><div class="rating-mdl n20 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">2,2</span><span class="stareval-review light"> 224 notes, 37 critiques</span></div>
# </div>
# </div>
# <div class="rating-item">
# <div class="rating-item-content js-user-friends-rating" data-entity-id="TW92aWU6MjI3NDYz" data-size="small" data-title="Mes amis ">
# <a class="rating-title" href="#">Mes amis </a>
# <div class="stareval stareval-small stareval-theme-default"><div class="rating-mdl n00 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note no-rating">--</span></div>
# </div>
# </div>
# </div>
# <div class="buttons-holder">
# <span class="ACrL3NACrlYW5jZS9maWxtLTIyNzQ2My8= button button-sm button-inverse-full">
# <span class="txt">Séances (973)</span>
# </span>
# <div class="js-nativebutton ad-nativebutton ad-item" id="dfp-nativebutton"></div>
# </div>
# </div>
# <div class="bam-container entity-bam"><div class="bam-cell bam-rating-user"><span class="user-rating-title">noter :</span><div class="js-user-rating" data-entity-id="TW92aWU6MjI3NDYz" data-show-suggestion="true" data-size="large" data-social-action-placement="actions_section" data-title=""><span class="user-rating stareval user-rating-large"><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">0.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">1</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">1.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">2</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">2.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">3</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">3.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">4</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">4.5</span></div><div class="rating-star tooltip-parent"><span class="tooltip tooltip-dark tooltip-child">5</span></div></span></div></div><div class="bam-cell bam-want-to-see js-user-want-to-see" data-classes="button icon icon-wish-full" data-content="Envie de voir" data-entity-id="TW92aWU6MjI3NDYz" data-social-action-placement="actions_section"><span class="button icon icon-wish-full">Envie de voir</span></div><div class="bam-cell bam-review js-user-review-link" data-classes="button icon icon-pen" data-content="Rédiger ma critique" data-entity-id="TW92aWU6MjI3NDYz"><span class="button icon icon-pen">Rédiger ma critique</span></div><div class="bam-cell bam-share"><div class="more-overlay js-more-overlay"><div class="more-overlay-trigger js-more-overlay-button"><div class="icon icon-3dots"></div></div><div class="more-overlay-content"><ul class="more-overlay-subcontent"><li class="more-overlay-item icon icon-add-to-collections js-add-to-collection" data-entity-id="TW92aWU6MjI3NDYz">Ajouter à une collection</li></ul><span aria-label="Partager ce contenu sur Whatsapp" class="ACraHRACr0cHM6Ly9hcGkud2hhdHNhcHAuY29tL3NlbmQ/dGV4dD1odHRwcyUzQSUyRiUyRnd3dy5hbGxvY2luZS5mciUyRmZpbG0lMkZmaWNoZWZpbG1fZ2VuX2NmaWxtJTNEMjI3NDYzLmh0bWw= button button-whatsapp-full js-share-btn more-overlay-button" data-gtm-push='{"event":"eventGA","eventCategory":"social","eventAction":"clicked-on-whatsapp","clicked_movie_id":227463,"movie_distributor":929}'><span class="txt">Partager sur WhatsApp</span></span><span aria-label="Partager ce contenu sur Facebook" class="ACraHRACr0cHM6Ly93d3cuZmFjZWJvb2suY29tL3NoYXJlci9zaGFyZXIucGhwP3U9aHR0cHMlM0ElMkYlMkZ3d3cuYWxsb2NpbmUuZnIlMkZmaWxtJTJGZmljaGVmaWxtX2dlbl9jZmlsbSUzRDIyNzQ2My5odG1s button button-fb-full js-share-btn more-overlay-button" data-gtm-push='{"event":"eventGA","eventCategory":"social","eventAction":"clicked-on-facebook","clicked_movie_id":227463,"movie_distributor":929}'><span class="txt">Partager sur Facebook</span></span><span aria-label="Partager ce contenu sur Twitter" class="ACraHRACr0cHM6Ly90d2l0dGVyLmNvbS9pbnRlbnQvdHdlZXQ/dGV4dD1NaW5lY3JhZnQlMkMlMjBMZSUyMEZpbG0mdXJsPWh0dHBzJTNBJTJGJTJGd3d3LmFsbG9jaW5lLmZyJTJGZmlsbSUyRmZpY2hlZmlsbV9nZW5fY2ZpbG0lM0QyMjc0NjMuaHRtbCZ2aWE9YWxsb2NpbmU= button button-tw-full js-share-btn more-overlay-button" data-gtm-push='{"event":"eventGA","eventCategory":"social","eventAction":"clicked-on-twitter","clicked_movie_id":227463,"movie_distributor":929}'><span class="txt">Partager sur Twitter</span></span></div></div></div></div>
# <div class="js-affinity-suggestions" data-entity-id="TW92aWU6MjI3NDYz"></div>
# <div class="js-nativevod ad-nativevod ad-item" id="dfp-nativevod"></div>
# <section class="section ovw ovw-synopsis" id="synopsis-details">
# <div class="titlebar section-title"><h2 class="titlebar-title titlebar-title-md">Synopsis</h2></div>
# <div class="certificate">
# <span class="certificate-text">Tout public</span>
# <div class="advice tooltip-anchor" data-tooltip='{"content":null,"event":"mouseover","position":"bottom"}'>
# </div>
# </div>
# <div class="content-txt">
# <p class="bo-p">Bienvenue dans l’univers de Minecraft où la créativité est essentielle à la survie ! Quatre outsiders – Garrett, Henry, Natalie et Dawn  – sont soudainement projetés à travers un mystérieux portail menant à La Surface – un incroyable monde cubique qui prospère grâce à l’imagination. Pour rentrer chez eux, il leur faudra maîtriser ce monde (et le protéger de créatures maléfiques comme les Piglins et les Zombies), tout en s’engageant dans une quête fantastique aux côtés de Steve, expert fabricateur. Cette aventure les poussera à être audacieux et à développer leur créativité. Autant de facultés dont ils auront besoin pour s’épanouir dans le monde réel.</p>
# </div>
# <div id="mobile-referrer-atf"></div>
# </section>
# <section class="section ovw">
# <div class="titlebar section-title"><h2 class="titlebar-title titlebar-title-md"><span class="ACrL3NACrlYW5jZS9maWxtLTIyNzQ2My8= titlebar-link">Séances</span></h2></div>
# <div class="titlebar"><h3 class="titlebar-title titlebar-title-xs">Chercher une séance</h3></div>
# <div class="ovw-search">
# <div class="js-search-location" data-placeholder="Ex : Nice, Bastille, 75001..." data-route='{"locationRoute":{"name":"moviepage_showtimes_place","defaultParameters":{"movie":227463},"objectParameters":{"localization":"id"}},"theaterRoute":{"name":"theater_showtimes","objectParameters":{"idTheater":"internalId"}},"searchRoute":{"name":"moviepage_showtimes_lookup","defaultParameters":{"movie":227463}}}'>
# <form action="/seance/film-227463/recherche/" aria-label="formulaire de recherche d'une salle de cinéma" autocomplete="off" class="form-holder theaters-form form form-localization" method="get" role="form">
# <fieldset class="form-field">
# <input class="form-text" id="showtimes_search_q" name="showtimes_search[q]" placeholder="Ex : Nice, Bastille, 75001..." required="required" type="text"/>
# <button aria-label="Ex : Nice, Bastille, 75001..." class="form-submit button button-md icon icon-search" title="Ex : Nice, Bastille, 75001..." type="submit"></button>
# </fieldset>
# </form>
# </div>
# </div>
# <div class="mdl-more gd small-crop">
# <ul class="">
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/seance/film-227463/pres-de-115755/" title="Paris">
#             Paris
#         </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/seance/film-227463/pres-de-113315/" title="Lyon">
#             Lyon
#         </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/seance/film-227463/pres-de-87914/" title="Marseille">
#             Marseille
#         </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/seance/film-227463/pres-de-85327/" title="Nice">
#             Nice
#         </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/seance/film-227463/pres-de-115774/" title="Paris 19e arrondissement">
#             Paris 19e arrondissement
#         </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/seance/film-227463/pres-de-95171/" title="Brest">
#             Brest
#         </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/seance/film-227463/pres-de-110514/" title="Clermont-Ferrand">
#             Clermont-Ferrand
#         </a>
# </li>
# </ul>
# <div class="gd-span-l-4-9 gd-span-m-4-9">
# <div class="more-trigger js-more-trigger" id="more-ovw-theaters">Voir plus de villes</div>
# <div class="row more-hidden gd gd-m-2 gd-l-2">
# <ul class="">
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/seance/film-227463/pres-de-96943/" title="Bordeaux">
#             Bordeaux
#         </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/seance/film-227463/pres-de-115768/" title="Paris 13e arrondissement">
#             Paris 13e arrondissement
#         </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/seance/film-227463/pres-de-98662/" title="Tours">
#             Tours
#         </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/seance/film-227463/pres-de-115435/" title="Annecy">
#             Annecy
#         </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/seance/film-227463/pres-de-115770/" title="Paris 15e arrondissement">
#             Paris 15e arrondissement
#         </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/seance/film-227463/pres-de-85268/" title="Cannes">
#             Cannes
#         </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/seance/film-227463/pres-de-111337/" title="Pau">
#             Pau
#         </a>
# </li>
# </ul>
# <ul class="">
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/seance/film-227463/pres-de-115772/" title="Paris 17e arrondissement">
#             Paris 17e arrondissement
#         </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/seance/film-227463/pres-de-121349/" title="Brétigny-sur-Orge">
#             Brétigny-sur-Orge
#         </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/seance/film-227463/pres-de-95640/" title="Nîmes">
#             Nîmes
#         </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/seance/film-227463/pres-de-95890/" title="Blagnac">
#             Blagnac
#         </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/seance/film-227463/pres-de-97612/" title="Montpellier">
#             Montpellier
#         </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/seance/film-227463/pres-de-100034/" title="Mont-de-Marsan">
#             Mont-de-Marsan
#         </a>
# </li>
# <li class="mdl-more-li">
# <a class="mdl-more-item" href="/seance/film-227463/pres-de-100691/" title="Saint-Étienne">
#             Saint-Étienne
#         </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="end-section-link-container">
# <span class="ACrL3NACrlYW5jZS9maWxtLTIyNzQ2My8= end-section-link" title="Voir toutes les séances (973)">Voir toutes les séances (973)</span>
# </div>
# </section>
# <div class="js-nativebannerope ad-nativebannerope ad-item" id="dfp-nativebanner-ope"></div>
# <section class="section ovw">
# <div class="titlebar section-title"><h2 class="titlebar-title titlebar-title-md"><a class="titlebar-link" href="/videos/fichefilm-227463/toutes/">Bande-annonce</a></h2></div>
# <div class="gd gd-gap-15 gd-xs-1 gd-s-3">
# <div class="card video-card video-card-col">
# <figure class="thumbnail">
# <div class="thumbnail-container">
# <img alt="image de Minecraft, Le Film Bande-annonce VF" class="thumbnail-img" data-src="https://fr.web.img4.acsta.net/c_208_117/img/7d/4c/7d4c9d433cc23f6bc5bec9d1b2a3902c.jpg" height="117" src="..." width="208"/>
# <span class="thumbnail-count">2:28</span>
# </div>
# </figure>
# <div class="meta">
# <div class="meta-title">
# <span class="ACrL3ZACrpZGVvL3BsYXllcl9nZW5fY21lZGlhPTIwNjE3MTA1JmNmaWxtPTIyNzQ2My5odG1s meta-title-link">Minecraft, Le Film Bande-annonce VF</span>
# </div>
# <div class="meta-sub light">
# <span>50 381 vues</span>
# </div>
# </div>
# </div>
# <div class="card video-card video-card-col">
# <figure class="thumbnail">
# <div class="thumbnail-container">
# <img alt="image de Minecraft, Le Film Bande-annonce VO STFR" class="thumbnail-img" data-src="https://fr.web.img4.acsta.net/c_208_117/img/7d/4c/7d4c9d433cc23f6bc5bec9d1b2a3902c.jpg" height="117" src="..." width="208"/>
# <span class="thumbnail-count">2:28</span>
# </div>
# </figure>
# <div class="meta">
# <div class="meta-title">
# <a class="meta-title-link" href="/video/player_gen_cmedia=20617104&amp;cfilm=227463.html">Minecraft, Le Film Bande-annonce VO STFR</a>
# </div>
# <div class="meta-sub light">
# <span>922 vues</span>
# </div>
# </div>
# </div>
# <div class="card video-card video-card-col">
# <figure class="thumbnail">
# <div class="thumbnail-container">
# <img alt="image de Minecraft, le film Bande-annonce VO STFR" class="thumbnail-img" data-src="https://fr.web.img6.acsta.net/c_208_117/img/f4/d1/f4d137757cbcac74f7c968a01e332b2f.jpg" height="117" src="..." width="208"/>
# <span class="thumbnail-count">2:28</span>
# </div>
# </figure>
# <div class="meta">
# <div class="meta-title">
# <a class="meta-title-link" href="/video/player_gen_cmedia=20612516&amp;cfilm=227463.html">Minecraft, le film Bande-annonce VO STFR</a>
# </div>
# <div class="meta-sub light">
# <span>13 659 vues</span>
# </div>
# </div>
# </div>
# <div class="card video-card video-card-col">
# <figure class="thumbnail">
# <div class="thumbnail-container">
# <img alt="image de Minecraft, le film Bande-annonce VF" class="thumbnail-img" data-src="https://fr.web.img6.acsta.net/c_208_117/img/f4/d1/f4d137757cbcac74f7c968a01e332b2f.jpg" height="117" src="..." width="208"/>
# <span class="thumbnail-count">2:28</span>
# </div>
# </figure>
# <div class="meta">
# <div class="meta-title">
# <a class="meta-title-link" href="/video/player_gen_cmedia=20612517&amp;cfilm=227463.html">Minecraft, le film Bande-annonce VF</a>
# </div>
# <div class="meta-sub light">
# <span>7 904 vues</span>
# </div>
# </div>
# </div>
# <div class="card video-card video-card-col">
# <figure class="thumbnail">
# <div class="thumbnail-container">
# <img alt="image de Minecraft Teaser VO STFR" class="thumbnail-img" data-src="https://fr.web.img5.acsta.net/c_208_117/img/e5/ff/e5ffcb51a96875efa8cf10ab65b2dba5.jpg" height="117" src="..." width="208"/>
# <span class="thumbnail-count">1:18</span>
# </div>
# </figure>
# <div class="meta">
# <div class="meta-title">
# <a class="meta-title-link" href="/video/player_gen_cmedia=20608386&amp;cfilm=227463.html">Minecraft Teaser VO STFR</a>
# </div>
# <div class="meta-sub light">
# <span>19 854 vues</span>
# </div>
# </div>
# </div>
# </div>
# </section>
# <div id="mobile-referrer-mtf"></div>
# <section class="section ovw">
# <div class="titlebar section-title"><h2 class="titlebar-title titlebar-title-md"><span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTIyNzQ2My9hY3R1Lw== titlebar-link">Dernières news</span></h2></div>
# <div class="hred">
# <div class="card news-card news-card-full cf"><figure class="thumbnail"><span class="ACrL2FACrydGljbGUvZmljaGVhcnRpY2xlX2dlbl9jYXJ0aWNsZT0xMDAwMTM2NjU3Lmh0bWw= thumbnail-container thumbnail-link" title="Minecraft : comment la saga aux 300 millions d'exemplaires vendus est devenue un film où Jack Black et Jason Momoa s'éclatent ?"><img alt="image de la news Minecraft : comment la saga aux 300 millions d'exemplaires vendus est devenue un film où Jack Black et Jason Momoa s'éclatent ?" class="thumbnail-img" data-src="https://fr.web.img5.acsta.net/c_640_360/img/9f/cb/9fcb9fb1f4daeb610662f0ea22e6917f.jpg" height="360" src="..." width="640"/></span></figure><div class="meta"><div class="meta-category">News - Sorties ciné</div><div class="meta-title"><a class="meta-title-link" href="/article/fichearticle_gen_carticle=1000136657.html">Minecraft : comment la saga aux 300 millions d'exemplaires vendus est devenue un film où Jack Black et Jason Momoa s'éclatent ?</a></div><div class="meta-date">mercredi 2 avril 2025</div></div></div> </div>
# <div class="hred">
# <div class="card news-card news-card-row cf"><figure class="thumbnail"><div class="thumbnail-container"><img alt="image de la news Minecraft : deux boîtes LEGO pour préparer l'arrivée du film !" class="thumbnail-img" data-src="https://fr.web.img4.acsta.net/c_400_225/img/21/4a/214a08ed165364a41e7ce21a9495c2b4.jpg" height="225" src="..." width="400"/></div></figure><div class="meta"><div class="meta-category">News - Insolite</div><div class="meta-title"><a class="meta-title-link" href="/article/fichearticle_gen_carticle=1000136577.html">Minecraft : deux boîtes LEGO pour préparer l'arrivée du film !</a></div><div class="meta-body">Ce mercredi 2 avril, les jeunes fans de "Minecraft" vont enfin pouvoir plonger dans l'univers du jeu vidéo sur grand écran.…</div><div class="meta-date">mardi 1 avril 2025</div></div></div> </div>
# <div class="hred">
# <div class="card news-card news-card-row cf"><figure class="thumbnail"><div class="thumbnail-container"><img alt="image de la news Au cinéma le 2 avril, ce sont les films à voir : Minecraft, Le Routard avec Christian Clavier, Cassandre..." class="thumbnail-img" data-src="https://fr.web.img3.acsta.net/c_400_225/img/1b/7c/1b7c1318db8daf1e593e08625a06fbc6.jpg" height="225" src="..." width="400"/></div></figure><div class="meta"><div class="meta-category">News - Sorties ciné</div><div class="meta-title"><a class="meta-title-link" href="/article/fichearticle_gen_carticle=1000136014.html">Au cinéma le 2 avril, ce sont les films à voir : Minecraft, Le Routard avec Christian Clavier, Cassandre...</a></div><div class="meta-body">Anecdotes de tournage, notes d'intention, informations cinéphiles : chaque semaine, découvrez les coulisses des sorties…</div><div class="meta-date">lundi 31 mars 2025</div></div></div> </div>
# <div class="hred">
# <div class="card news-card news-card-row cf"><figure class="thumbnail"><div class="thumbnail-container"><img alt="image de la news Jugé &quot;pathétique et ringard&quot;... Le remake de ce film d'aventure culte des années 90 sortira fin 2025" class="thumbnail-img" data-src="https://fr.web.img4.acsta.net/c_400_225/img/bb/43/bb43e96a5ee18ee7e4412afdbb7595a8.jpg" height="225" src="..." width="400"/></div></figure><div class="meta"><div class="meta-category">News - Tournages</div><div class="meta-title"><a class="meta-title-link" href="/article/fichearticle_gen_carticle=1000121785.html">Jugé "pathétique et ringard"... Le remake de ce film d'aventure culte des années 90 sortira fin 2025</a></div><div class="meta-body">Une réinterprétation du film d’horreur “Anaconda, le prédateur” de 1997 verra le jour en 2025. Mais attention, avec Paul…</div><div class="meta-date">samedi 4 janvier 2025</div></div></div> </div>
# <div class="hred">
# <div class="card news-card news-card-row cf"><figure class="thumbnail"><div class="thumbnail-container"><img alt="image de la news &quot;Ça a le don de m'énerver&quot; : pourquoi les fans détestent cette bande-annonce avec Jason Momoa vue 20 millions de fois ?" class="thumbnail-img" data-src="https://fr.web.img3.acsta.net/c_400_225/img/d7/a3/d7a39372864c99570240da18f04ab00b.jpg" height="225" src="..." width="400"/></div></figure><div class="meta"><div class="meta-category">News - Tournages</div><div class="meta-title"><a class="meta-title-link" href="/article/fichearticle_gen_carticle=1000101847.html">"Ça a le don de m'énerver" : pourquoi les fans détestent cette bande-annonce avec Jason Momoa vue 20 millions de fois ?</a></div><div class="meta-body">La bande-annonce de l'adaptation ciné du jeu vidéo "Minecraft" a été dévoilée mercredi. Depuis, la vidéo a été vue plus…</div><div class="meta-date">vendredi 6 septembre 2024</div></div></div> </div>
# <div class="end-section-link-container">
# <a class="end-section-link" href="/film/fichefilm-227463/actu/" title="20 news sur ce film">20 news sur ce film</a>
# </div>
# </section>
# <section class="section ovw">
# <div class="titlebar section-title"><h2 class="titlebar-title titlebar-title-md"><span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTIyNzQ2My9jYXN0aW5nLw== titlebar-link">Acteurs et actrices</span></h2></div>
# <div class="gd gd-gap-20 gd-xs-2 gd-s-4">
# <div class="card person-card">
# <figure class="thumbnail">
# <span class="ACrL3BACrlcnNvbm5lL2ZpY2hlcGVyc29ubmVfZ2VuX2NwZXJzb25uZT0yMTk3MS5odG1s thumbnail-container thumbnail-link" title="Jack Black">
# <img alt="photo de Jack Black" class="thumbnail-img" data-src="https://fr.web.img6.acsta.net/c_162_216/pictures/15/12/01/10/14/192452.jpg" height="216" src="..." width="162"/>
# </span>
# </figure>
# <div class="meta">
# <div class="meta-title">
# <a class="meta-title-link" href="/personne/fichepersonne_gen_cpersonne=21971.html">Jack Black</a>
# </div>
# <div class="meta-sub light">
#               Rôle : Steve
#             </div>
# </div>
# </div>
# <div class="card person-card">
# <figure class="thumbnail">
# <span class="ACrL3BACrlcnNvbm5lL2ZpY2hlcGVyc29ubmVfZ2VuX2NwZXJzb25uZT0xMDUxMjcuaHRtbA== thumbnail-container thumbnail-link" title="Jason Momoa">
# <img alt="photo de Jason Momoa" class="thumbnail-img" data-src="https://fr.web.img4.acsta.net/c_162_216/pictures/17/11/16/14/08/4596459.jpg" height="216" src="..." width="162"/>
# </span>
# </figure>
# <div class="meta">
# <div class="meta-title">
# <a class="meta-title-link" href="/personne/fichepersonne_gen_cpersonne=105127.html">Jason Momoa</a>
# </div>
# <div class="meta-sub light">
#               Rôle : Garrett Garrison
#             </div>
# </div>
# </div>
# <div class="card person-card">
# <figure class="thumbnail">
# <span class="ACrL3BACrlcnNvbm5lL2ZpY2hlcGVyc29ubmVfZ2VuX2NwZXJzb25uZT02NDk5NjQuaHRtbA== thumbnail-container thumbnail-link" title="Danielle Brooks">
# <img alt="photo de Danielle Brooks" class="thumbnail-img" data-src="https://fr.web.img4.acsta.net/c_162_216/pictures/24/01/16/12/41/3436376.jpg" height="216" src="..." width="162"/>
# </span>
# </figure>
# <div class="meta">
# <div class="meta-title">
# <a class="meta-title-link" href="/personne/fichepersonne_gen_cpersonne=649964.html">Danielle Brooks</a>
# </div>
# <div class="meta-sub light">
#               Rôle : Dawn
#             </div>
# </div>
# </div>
# <div class="card person-card">
# <figure class="thumbnail">
# <span class="ACrL3BACrlcnNvbm5lL2ZpY2hlcGVyc29ubmVfZ2VuX2NwZXJzb25uZT05NDI1OTAuaHRtbA== thumbnail-container thumbnail-link" title="Emma Myers">
# <img alt="photo de Emma Myers" class="thumbnail-img" data-src="https://fr.web.img3.acsta.net/c_162_216/pictures/22/11/26/18/32/2255098.jpg" height="216" src="..." width="162"/>
# </span>
# </figure>
# <div class="meta">
# <div class="meta-title">
# <a class="meta-title-link" href="/personne/fichepersonne_gen_cpersonne=942590.html">Emma Myers</a>
# </div>
# <div class="meta-sub light">
#               Rôle : Natalie
#             </div>
# </div>
# </div>
# </div>
# <div class="end-section-link-container">
# <a class="end-section-link" href="/film/fichefilm-227463/casting/" title="Casting complet et équipe technique">Casting complet et équipe technique</a>
# </div>
# </section>
# <div id="mobile-referrer-btf"></div>
# <section class="section ovw">
# <div class="titlebar section-title"><h2 class="titlebar-title titlebar-title-md"><span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTIyNzQ2My9jcml0aXF1ZXMvcHJlc3NlLw== titlebar-link">Critiques Presse</span></h2></div>
# <div class="row reviews-press-list gd gd-xs-1 gd-m-2">
# <ul class="item-holder">
# <li class="item">
# <div class="stareval stareval-medium stareval-theme-default"><span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTIyNzQ2My9jcml0aXF1ZXMvcHJlc3NlLyNwcmVzc3JldmlldzEwMDAwNDQyNDg= stareval-link" title="Pas mal"><div class="rating-mdl n30 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div></span><span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTIyNzQ2My9jcml0aXF1ZXMvcHJlc3NlLyNwcmVzc3JldmlldzEwMDAwNDQyNDg= stareval-link stareval-link-info js-anchor-link">20 Minutes</span></div>
# </li>
# <li class="item">
# <div class="stareval stareval-medium stareval-theme-default"><span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTIyNzQ2My9jcml0aXF1ZXMvcHJlc3NlLyNwcmVzc3JldmlldzEwMDAwNDQwODc= stareval-link" title="Pas mal"><div class="rating-mdl n30 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div></span><span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTIyNzQ2My9jcml0aXF1ZXMvcHJlc3NlLyNwcmVzc3JldmlldzEwMDAwNDQwODc= stareval-link stareval-link-info js-anchor-link">Nice-Matin</span></div>
# </li>
# <li class="item">
# <div class="stareval stareval-medium stareval-theme-default"><span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTIyNzQ2My9jcml0aXF1ZXMvcHJlc3NlLyNwcmVzc3JldmlldzEwMDAwNDQyMTU= stareval-link" title="Pas terrible"><div class="rating-mdl n20 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div></span><span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTIyNzQ2My9jcml0aXF1ZXMvcHJlc3NlLyNwcmVzc3JldmlldzEwMDAwNDQyMTU= stareval-link stareval-link-info js-anchor-link">Dernières Nouvelles d'Alsace</span></div>
# </li>
# <li class="item">
# <div class="stareval stareval-medium stareval-theme-default"><span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTIyNzQ2My9jcml0aXF1ZXMvcHJlc3NlLyNwcmVzc3JldmlldzEwMDAwNDQyMTY= stareval-link" title="Pas terrible"><div class="rating-mdl n20 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div></span><span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTIyNzQ2My9jcml0aXF1ZXMvcHJlc3NlLyNwcmVzc3JldmlldzEwMDAwNDQyMTY= stareval-link stareval-link-info js-anchor-link">Le Dauphiné Libéré</span></div>
# </li>
# <li class="item">
# <div class="stareval stareval-medium stareval-theme-default"><span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTIyNzQ2My9jcml0aXF1ZXMvcHJlc3NlLyNwcmVzc3JldmlldzEwMDAwNDQyMDE= stareval-link" title="Pas terrible"><div class="rating-mdl n20 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div></span><span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTIyNzQ2My9jcml0aXF1ZXMvcHJlc3NlLyNwcmVzc3JldmlldzEwMDAwNDQyMDE= stareval-link stareval-link-info js-anchor-link">Le Monde</span></div>
# </li>
# </ul>
# <ul class="item-holder">
# <li class="item">
# <div class="stareval stareval-medium stareval-theme-default"><span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTIyNzQ2My9jcml0aXF1ZXMvcHJlc3NlLyNwcmVzc3JldmlldzEwMDAwNDQyMDI= stareval-link" title="Pas terrible"><div class="rating-mdl n20 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div></span><span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTIyNzQ2My9jcml0aXF1ZXMvcHJlc3NlLyNwcmVzc3JldmlldzEwMDAwNDQyMDI= stareval-link stareval-link-info js-anchor-link">Le Parisien</span></div>
# </li>
# <li class="item">
# <div class="stareval stareval-medium stareval-theme-default"><span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTIyNzQ2My9jcml0aXF1ZXMvcHJlc3NlLyNwcmVzc3JldmlldzEwMDAwNDQyNjc= stareval-link" title="Pas terrible"><div class="rating-mdl n20 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div></span><span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTIyNzQ2My9jcml0aXF1ZXMvcHJlc3NlLyNwcmVzc3JldmlldzEwMDAwNDQyNjc= stareval-link stareval-link-info js-anchor-link">Les Fiches du Cinéma</span></div>
# </li>
# <li class="item">
# <div class="stareval stareval-medium stareval-theme-default"><span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTIyNzQ2My9jcml0aXF1ZXMvcHJlc3NlLyNwcmVzc3JldmlldzEwMDAwNDQyNDk= stareval-link" title="Pas terrible"><div class="rating-mdl n20 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div></span><span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTIyNzQ2My9jcml0aXF1ZXMvcHJlc3NlLyNwcmVzc3JldmlldzEwMDAwNDQyNDk= stareval-link stareval-link-info js-anchor-link">Ouest France</span></div>
# </li>
# <li class="item">
# <div class="stareval stareval-medium stareval-theme-default"><span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTIyNzQ2My9jcml0aXF1ZXMvcHJlc3NlLyNwcmVzc3JldmlldzEwMDAwNDQyMDM= stareval-link" title="Très mauvais"><div class="rating-mdl n10 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div></span><span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTIyNzQ2My9jcml0aXF1ZXMvcHJlc3NlLyNwcmVzc3JldmlldzEwMDAwNDQyMDM= stareval-link stareval-link-info js-anchor-link">Première</span></div>
# </li>
# <li class="item">
# <div class="stareval stareval-medium stareval-theme-default"><span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTIyNzQ2My9jcml0aXF1ZXMvcHJlc3NlLyNwcmVzc3JldmlldzEwMDAwNDQyMjQ= stareval-link" title="Très mauvais"><div class="rating-mdl n10 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div></span><span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTIyNzQ2My9jcml0aXF1ZXMvcHJlc3NlLyNwcmVzc3JldmlldzEwMDAwNDQyMjQ= stareval-link stareval-link-info js-anchor-link">Télérama</span></div>
# </li>
# </ul>
# </div>
# <p class="press-review-notice">
#             Chaque magazine ou journal ayant son propre système de notation, toutes les notes attribuées sont remises au barême de AlloCiné, de 1 à 5 étoiles. Retrouvez plus d'infos sur notre page <span class="ACrL3NACrlcnZpY2Uvbm90ZS1wcmVzc2UuaHRtbA==">Revue de presse</span> pour en savoir plus.
#     </p>
# <div class="end-section-link-container">
# <a class="end-section-link" href="/film/fichefilm-227463/critiques/presse/" title="10 articles de presse">10 articles de presse</a>
# </div>
# </section>
# <section class="section ovw">
# <div class="titlebar section-title"><h2 class="titlebar-title titlebar-title-md"><span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTIyNzQ2My9jcml0aXF1ZXMvc3BlY3RhdGV1cnMv titlebar-link">Critiques Spectateurs : ils ont aimé</span></h2><div class="light titlebar-subtile"><span class="titlebar-subtile-txt">Meilleures critiques les plus utiles</span></div></div>
# <div class="hred review-card cf" id="review_1034717547">
# <div class="review-card-aside">
# <div class="review-card-user-infos cf">
# <figure class="thumbnail">
# <span class="ACrL21ACrlbWJyZS1aMjAwNjEwMDExMTA4MzM4OTM0NTc4MTMv thumbnail-container thumbnail-link" title="Cécilia S">
# <img alt="Cécilia S" class="thumbnail-img" data-src="https://fr.web.img3.acsta.net/c_80_80/users/02/3/1/8/Z20061001110833893457813/img/kbphjlyd.vzh.jpg" height="80" src="..." width="80"/>
# </span>
# </figure>
# <div class="meta">
# <div class="meta-title">
# <span class="ACrL21ACrlbWJyZS1aMjAwNjEwMDExMTA4MzM4OTM0NTc4MTMv">Cécilia S</span>
# </div>
# <p class="meta-content light">
# <span class="ACrL21ACrlbWJyZS1aMjAwNjEwMDExMTA4MzM4OTM0NTc4MTMvY29tbXVuYXV0ZS9hYm9ubmVzLw== item-profil">
#                     18 abonnés
#                 </span>
# ...
#     if(typeof window[n]!=="function"){window[n]=e;if(window.addEventListener){window.addEventListener("message",t,false)}else{window.attachEvent("onmessage",t)}}}e("__tcfapi","__tcfapiBuffer","__tcfapiCall","__tcfapiReturn");a("__tcfapiLocator");(function(e){
#     var t=document.createElement("script");t.id="spcloader";t.type="text/javascript";t.async=true;t.src="https://sdk.privacy-center.org/"+e+"/loader.js?target_type=notice&target=TtwHt2xD";t.charset="utf-8";var n=document.getElementsByTagName("script")[0];n.parentNode.insertBefore(t,n)})('e23a01f6-a508-4e71-8f50-c1a9cae7c0d0')})();</script>
# <!-- DIDOMI CMP SCRIPT ENDS -->
# <script type="text/javascript">
#     var dataLayerJan = {"site_route":"moviepage","entity_type":"movie","movie":"227463|minecraft_le_film","movie_entity":"227463|minecraft_le_film","movie_id":227463,"movie_title":"minecraft_le_film","movie_status":"in_theaters","movie_genres":"adventure|comedy|family","movie_distributor_name":"warner_bros_france","movie_distributor_id":929,"vod_providers":"undefined","svod_providers":"undefined","replay_providers":"undefined","entity_tag_id":"5261|1099|5267|5265|1108|2700|5217|5271|2437|5324|1104"};
#         window.jan=window.jan||{},jan.cmd=jan.cmd||[],jancmd=function(){jan.cmd.push(arguments)};
#     </script>
# <script type="text/javascript">
#         var JadConfig = {"provider":"dfp","system":"jad","account-id":"\/120157152","account-first-level":"\/ALLOCINE_FR_WEB","tag-id":"\/120157152\/ALLOCINE_FR_WEB","tag-other-levels":"\/moviepage\/moviepage","navEgg":null,"targeting":{"site":"allocine","site_route":"moviepage","site_section":"moviepage","environment":"web","genre":["13001","13005","13036"],"actor":["21971","105127","649964"],"nationality":"5002","releasedate":"2025-04-02","production_year":"2025","movie_id":"227463","movie_label":"minecraft_le_film","movie_isshowtime":"1","movie_distributors":"929","coming_soon":"0","press_rating":"2","user_rating":"2.2","editorial_rating":"0","tags":["5261","1099","5267","5265","1108","2700","5217","5271","2437","5324","1104"],"is_svod_originals":"0","is_svod_exclusive":"0","company":["20","929","8381"],"is_for_kids":"1","certificate":"U"},"autoRefresh":true,"cmpPaywall":{"name":"didomi","siteId":"e23a01f6-a508-4e71-8f50-c1a9cae7c0d0","noticeId":"TtwHt2xD","paywall":{"clientId":"AVvF60FpOZcS6UoBe6sf8isBLYwzuLgMQCnNdE-FvpoW_OhR8P6zERqhyuIBGPOxqrTHKxv7QxsXnfck","planId":"P-66F73522PX986223DMBQZG5A","tosUrl":"\/service\/cgv.html","touUrl":"\/service\/conditions.html","privacyUrl":"\/service\/charte.html"},"includeCmp":false},"customInterstitialCapping":1,"adsMapping":{"interstitial":"dfp-interstitial","header":"dfp-masthead","inread1":"dfp-inread","rectangle_atf":"dfp-atf","rectangle_mtf":"dfp-mtf","rectangle_btf":"dfp-btf","rectangle_mtf_2":"dfp-autopromo","rectangle_atf_diapo":"dfp-slideshow","slideshow_native_banner":"dfp-slideshownativebanner","imagead":"dfp-imagead","header_link":"dfp-headerlink","footer":"dfp-footer","pulse":"dfp-pulse","native_banner":"dfp-nativebanner","native_banner_ope":"dfp-nativebanner-ope","native_button":"dfp-nativebutton","native_rectangle":"dfp-nativerectangle","native_VOD":"dfp-nativevod","native_booking":"dfp-nativebooking","inread_added":"dfp-added-ad"}};
#         var JadIds    = ["dfp-interstitial","dfp-headerlink","dfp-masthead","dfp-nativebanner","dfp-nativebutton","dfp-nativevod","dfp-nativebanner-ope","dfp-atf","dfp-atf","dfp-mtf","dfp-mtf","dfp-autopromo","dfp-autopromo","dfp-btf","dfp-btf","dfp-footer","dfp-pulse"];
#         var WadsKeywords = {"route":"moviepage","site":"allocine_fr","page":"fichefilm","mode":"async","movie":"227463","genre":"13001|13005|13036","distributors":"929","kids":"1","tags":"5261|1099|5267|5265|1108|2700|5217|5271|2437|5324|1104","nationality":"5002","releasedate":"2025-04-02","is_netflix":"0","is_amazon":"0"};
#     </script>
# <script type="text/javascript">(function (win) {
#     win.AC = win.AC || {};
#     AC.config = {"releaseWeekDay":"Wednesday","locale":"fr_FR","lang":"fr","brand":"allocine","siteKey":"fr","graphCountryName":"FRANCE","display_provider":"jad","asset_version":"__GIT_COMMIT__","env":"prod","assetsUrls":{"css":{"secondary":"https:\/\/assets.allocine.fr\/skin\/css\/allocine\/secondary-styles.min.5a27fc87.css","font":"https:\/\/assets.allocine.fr\/skin\/css\/allocine\/font.min.7c570837.css"},"images":{"bronson":"https:\/\/assets.allocine.fr\/skin\/img\/userspace\/bronson.e492ec8e.gif","cineRelax":"https:\/\/assets.allocine.fr\/skin\/img\/logo-cine-relax.9ddea53f.svg","etoile":"https:\/\/assets.allocine.fr\/skin\/img\/etoiles.766780d2.png","ghostBuster":"https:\/\/assets.allocine.fr\/skin\/img\/userspace\/ghostbuster.7c731e13.png","logo":"https:\/\/assets.allocine.fr\/skin\/img\/logo-allocine.7e88ee87.svg","logoDark":"https:\/\/assets.allocine.fr\/skin\/img\/allocine\/logo-main-dark.536669e5.svg","macaron":"https:\/\/assets.allocine.fr\/skin\/img\/macaron.363298ee.png","notFound":"https:\/\/assets.allocine.fr\/skin\/img\/userspace\/not-found.dec1f46f.gif","onboarding":"https:\/\/assets.allocine.fr\/skin\/img\/allocine\/onboarding.a32c4541.png","rewind2024":"https:\/\/assets.allocine.fr\/skin\/img\/allocine\/rewind2024\/rewind-dark.d14607af.png","seriously":"https:\/\/assets.allocine.fr\/skin\/img\/seriously.ffccba64.gif","suggestions":"https:\/\/assets.allocine.fr\/skin\/img\/suggestions.0009180e.png","walle":"https:\/\/assets.allocine.fr\/skin\/img\/userspace\/walle.5d973cbb.png"}},"webedia_websites":["allocine.fr","www.academiedugout.fr","www.canalblog.com","www.over-blog.com","www.confidentielles.com","www.750g.com","www.alibabuy.com","www.chartsinfrance.net","www.dailyconso.com","www.easyvols.fr","www.easyvoyage.com","www.exponaute.com","www.forumjv.com","fr.ign.com","jeu.info","www.jeuxvideo.com","www.lebonguide.com","www.lofficielmode.com","www.millenium.org","www.purebreak.com","www.purecine.com","www.purefamille.com","www.purfans.com","www.pureloisirs.com","www.ozap.com","www.purepeople.com","www.puresaveurs.com","www.shopoon.fr","www.puresweethome.com","www.puretrend.com","www.terrafemina.com","www.yasmina.com","www.atyabtabkha.3a2ilati.com","www.3a2ilati.com","www.mashaheeri.com","www.mazyun.com","www.beyazperde.com","www.filmstarts.de","www.moviepilot.de","www.gamestar.de","www.onlinewelten.com","de.ign.com","www.gamespilot.de","www.heimgourmet.com","www.easyvoyage.de","www.adorocinema.com","br.ign.com","www.purepeople.com.br","www.purebreak.com.br","www.pureviagem.com.br","www.tudogostoso.com.br","www.receitas-sem-fronteiras.com","www.easyvoyage.co.uk","www.dealchecker.co.uk","www.gourmandize.com","www.sensacine.com","www.3djuegos.com","es.ign.com","www.easyviajar.com","www.rebanando.com","www.easyviaggio.com","www.tribugolosa.com"],"hosts":{"assets":"https:\/\/assets.allocine.fr","secure":"https:\/\/secure.allocine.fr","secureApi":"https:\/\/api-secure.allocine.fr","validation":"https:\/\/secure.allocine.fr","sso":"https:\/\/sso.allocine.fr","graph":"https:\/\/graph.allocine.fr","hostname":"allocine.fr"},"jan_config":{"src":"https:\/\/cdn.lib.getjan.io\/library\/allocine.js"},"ads":{"displayProvider":"jad","prerollProvider":"jad","postrollProvider":null,"postrollTrailerProvider":"jad","postrollProxy":"\/\/videos.allocine.fr","atf":"atf","slideshow":"slideshow","slideshownativebanner":"slideshownativebanner","positions":"dfp-atf,dfp-mtf,dfp-btf,dfp-interstitial,dfp-masthead,dfp-footer,dfp-slideshow,dfp-slideshownativebanner,dfp-sticky-amp,,,dfp-inread,,,,dfp-headerlink,,dfp-autopromo,dfp-pulse,dfp-nativebanner,dfp-nativebanner-ope,dfp-nativerectangle,dfp-nativebutton,dfp-nativevod,dfp-nativebooking,","nativebooking":"nativebooking"},"secureApiPartnerKey":"000042532791","facebook":{"appId":"99197768694","version":"v3.2","permissions":"public_profile email user_friends"},"google":{"appId":"472230823030.apps.googleusercontent.com","apiKey":"pxKT_spGOdGnt7MVJXcTGCGr","permissions":"https:\/\/www.googleap ...
#     AC.routing = {"base_url":"","routes":{"rewind_conf_json":{"tokens":[["text","\/_\/rewind_config.dd7c406038da4d5735d4f7bfad2eb0fa8927a26f.json"]],"defaults":{"_controller":"AppBundle\\Rewind\\Controller\\RewindConfController::rewindAction","_format":"json","options":{"expose":true},"_cache_control":{"enabled":true,"ttl":3600},"_universe":"default"},"requirements":[],"hosttokens":[],"methods":[],"schemes":[]},"fos_js_routing_js":{"tokens":[["variable",".","js|json","_format",true],["text","\/js\/routing"]],"defaults":{"_controller":"fos_js_routing.controller::indexAction","_format":"js","_cache_control":{"enabled":true,"ttl":3600},"_universe":"default"},"requirements":{"_format":"js|json"},"hosttokens":[],"methods":["GET"],"schemes":[]},"allocine__moviepage":{"tokens":[["text",".html"],["variable","=","[1-9]\\d*","movie",true],["text","\/film\/fichefilm_gen_cfilm"]],"defaults":{"_controller":"AppBundle\\Controller\\MoviePageController::indexAction","_api":[{"entity":"MOVIE","mainParam":"movie","description":"Homepage","params":{"movie":"MOVIE"}}],"_brand":"allocine","_cache_control":{"enabled":true,"ttl":3600},"_universe":"moviepage"},"requirements":{"movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"],"schemes":[]},"allocine__moviepage_showtimes":{"tokens":[["text","\/"],["variable","-","[1-9]\\d*","movie",true],["text","\/seance\/film"]],"defaults":{"_controller":"AppBundle\\Controller\\MoviePageController::showtimesAction","_api":[{"entity":"MOVIE","mainParam":"movie","description":"Showtimes","params":{"movie":"MOVIE"}}],"_brand":"allocine","_cache_control":{"enabled":true,"ttl":3600},"_universe":"moviepage"},"requirements":{"movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"],"schemes":[]},"allocine__moviepage_showtimes_place":{"tokens":[["text","\/"],["variable","-","\\d+","localization",true],["text","\/pres-de"],["variable","-","[1-9]\\d*","movie",true],["text","\/seance\/film"]],"defaults":{"_controller":"AppBundle\\Controller\\MoviePageController::showtimesPlaceAction","_brand":"allocine","_cache_control":{"enabled":true,"ttl":3600},"_universe":"moviepage"},"requirements":{"localization":"\\d+","movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"],"schemes":[]},"allocine__moviepage_showtimes_my_theaters":{"tokens":[["text","\/favoris\/seances\/"],["variable","-","[1-9]\\d*","movie",true],["text","\/seance\/film"]],"defaults":{"_controller":"AppBundle\\Controller\\MoviePageController::showtimesMyTheatersAction","_brand":"allocine","_cache_control":{"enabled":true,"ttl":3600},"_universe":"moviepage"},"requirements":{"movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"],"schemes":[]},"allocine__moviepage_showtimes_lookup":{"tokens":[["text","\/recherche\/"],["variable","-","[1-9]\\d*","movie",true],["text","\/seance\/film"]],"defaults":{"_controller":"AppBundle\\Controller\\MoviePageController::showtimesLookupAction","_brand":"allocine","_cache_control":{"enabled":true,"ttl":3600},"_universe":"moviepage"},"requirements":{"movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"],"schemes":[]},"allocine__moviepage_videos_trailer":{"tokens":[["text",".html"],["variable","=","[1-9]\\d*","movie",true],["text","&cfilm"],["variable","=","[1-9]\\d*","idMedia",true],["text","\/video\/player_gen_cmedia"]],"defaults":{"_controller":"AppBundle\\Controller\\MoviePageController::videosTrailerAction","_brand":"allocine","_cache_control":{"enabled":true,"ttl":3600},"_universe":"moviepage"},"requirements":{"idMedia":"[1-9]\\d*","movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"],"schemes":[]},"allocine__moviepage_all_videos_trailer":{"tokens":[["text","\/toutes\/"],["variable","-","[1-9]\\d*","movie",true],["text","\/videos\/fichefilm"]],"defaults":{"_controller":"AppBundle\\Controller\\MoviePageController::allVideosTrailerAction","_brand":"allocine","_cache_control":{"enable ...
#     AC.route = 'moviepage';
# }(window));
# </script>
# <script src="https://assets.allocine.fr/js/website/translations-3c2c9b3a976e5b6a646dc67d14f21fd0.fr_FR.js"></script>
# <script src="https://assets.allocine.fr/js/website/website-common.e461f236e0f6bb5d45c6.js" type="text/javascript"></script>
# <script defer="" src="https://assets.allocine.fr/js/website/moviepage.f2810555d041a1da8938.js" type="text/javascript"></script>
# <script type="text/javascript">
#     var dataLayer = dataLayer || [{"site_route":"moviepage","site_section":"movie","movie_id":227463,"movie_eidr_id":null,"movie_isan_id":null,"movie_label":"minecraft_le_film","movie_isshowtime":1,"movie_distributors":929,"genre":"13001=aventure&13005=com\u00e9die&13036=famille","releasedate":"2025-04-02","coming_soon":0,"actor":"21971,105127,649964","actor_voice":"","actor_local_voice":"","director":"","nationality":"5002","press_rating":2,"user_rating":2.2,"is_netflix":0,"is_amazon":0,"is_disney":0,"is_mycanal":0,"is_svod_originals":0,"is_svod_exclusive":0,"company":[20,929,8381],"svod_providers":[],"vod_providers":[],"tags":[5261,1099,5267,5265,1108,2700,5217,5271,2437,5324,1104]}];
# </script>
# <noscript>
# <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-PL6PBF" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <script type="text/javascript">
#             var asyncDataLayers = [];
#             var jsEntities = {"TW92aWU6MjI3NDYz":{"id":"TW92aWU6MjI3NDYz","title":"Minecraft, Le Film","social":{"user_note_i_want_to_see_count":1723},"flags":{"isComingSoon":false},"releaseDate":"2025-04-02T00:00:00+02:00","poster":{"__typename":"InternalImage","id":"SW1hZ2U6OTAwMTgxNTMwNQ==","internalId":9001815305,"url":"https:\/\/fr.web.img5.acsta.net\/img\/3e\/61\/3e619c6423fd2c82be9ec8b727aa217b.jpg","path":"\/img\/3e\/61\/3e619c6423fd2c82be9ec8b727aa217b.jpg"},"nationality":[{"id":5002,"name":"USA","localizedName":"U.S.A."}],"productionYear":2025,"rules":{"rating":{"has_warning_message":false,"has_mandatory_review":false}}}};
#         </script>
# <script>
#     (function(win, undefined) {
#         var tests = [];
#
#         // add tests here
#         tests.push(function() {
#             return 'CSS' in win && CSS.supports('display', 'grid');
#         });
#
#         // run all tests
#         var length = tests.length;
#         var idx = 0;
#         var supported = true;
#
#         for (idx = 0; supported && idx < length; idx += 1) {
#             supported = tests[idx]();
#         }
#
#         // display banner
#         if (!supported) {
#             var doc = win.document;
#             var alertBanner = doc.createElement('div');
#             var alertContent = alertBanner.cloneNode('div'); // performence best pratice
#             var bannerText = doc.createTextNode("La version de votre navigateur n'est plus supportée, l'expérience sur le site sera dégradée. Si vous ne pouvez ni mettre à jour votre navigateur, ni en changer, sachez que le site est consultable sur mobile à la même adresse.");
#
#             alertBanner.className = "alert-deprecated-banner alert-info";
#             alertContent.className = "alert-content";
#
#             var body = doc.body;
#             var head = doc.getElementsByTagName('head')[0];
#
#             var header = doc.getElementById('main-header');
#             var link = doc.createElement('link');
#
#             alertContent.appendChild(bannerText);
#             alertBanner.appendChild(alertContent);
#
#             body.insertBefore(alertBanner, header || body.firstChild);
#             body.className += ' deprecated';
#
#             // @todo css deprecated
#             link.setAttribute('href', 'https\u003A\/\/assets.allocine.fr\/skin\/css\/allocine\/deprecated.min.73cbaa92.css');
#             link.setAttribute('rel', 'stylesheet');
#             link.setAttribute('type', 'text/css');
#             head.appendChild(link);
#         }
#     })(window);
# </script>
# </div>
# </body>

# %% [markdown]
# For title
# ```html
# <div class="titlebar-title titlebar-title-lg">Le Grand Bain</div>
# ```
# For the synopsis
#
# ```html
# <section class="section ovw ovw-synopsis" id="synopsis-details">
#
#       <div class="content-txt">
#
#               C’est dans les couloirs de leur piscine municipale que Bertrand, Marcus, Simon, Laurent, Thierry et les autres s’entraînent sous l’autorité toute relative de Delphine, ancienne gloire des bassins. Ensemble, ils se sentent libres et utiles. Ils vont mettre toute leur énergie dans une discipline jusque-là propriété de la gent féminine : la natation synchronisée. Alors, oui c’est une idée plutôt bizarre, mais ce défi leur permettra de trouver un sens à leur vie...
#       </div>
#
#       </section>
# ```

# %%
for elem in soup.find_all("div", attrs={"class": "titlebar-title titlebar-title-lg"}):
    # Just like that
    print(elem.text)

# Get the synopsis section
for elem in soup.find_all("section", attrs={"id": "synopsis-details"}):
    # Get the text of the synopsis
    for elem2 in elem.find_all("div", attrs={"class":"content-txt"}):
        # Just like that
        print(elem2.text)

# %% [markdown]
# 1) Automate this script for the entire list of movies.
#
# 2) Put the information in three lists (`film_links`, `title`, `synopsis`).
#
# 3) Create a `DataFrame` object from the `pandas` library that you will have to install. This dataframe will have to include these three informations in three columns.
#
# 4) Save this dataframe in a CSV file.
#
# And here's your first real scrap, you're real hackers now.

# %%
import time
import random
from random import randint
from bs4 import BeautifulSoup
import requests

url = "http://www.allocine.fr/"
r = requests.get(url)
soup = BeautifulSoup(r.content, "lxml")

soup = soup.find("body") ## only the body from the html page

#---------------------------------------------
#---------------------------------------------
#---------------------------------------------

links = []
movie_links = []
titles = []

for elem in soup.find_all("a", attrs={"class": "meta-title meta-title-link"}):
    links.append(elem.get("href"))

"""
movie_links = ["http://www.allocine.fr" + href for href in links if "film" in href] # <<<<<<<<<<<<<<


#---------------------------------------------
#---------------------------------------------

for elem in links:
    if "film" in elem:
        movie_links.append("http://www.allocine.fr" + elem)
"""

#---------------------------------------------
#---------------------------------------------
#---------------------------------------------

"""
for elem in links:
    if "film" in elem:
        for a in soup.find_all("a", attrs={"class": "meta-title meta-title-link"}):
            title.append(a.get("title"))
            print(a.get("title"))
print(title)
"""

for a in soup.find_all("a", attrs={"class": "meta-title meta-title-link"}):
    href = a.get("href")
    if "film" in href:
        movie_links.append("http://www.allocine.fr" + href)
        title_text = a.get("title")
        titles.append(title_text)
        print(title_text)

#---------------------------------------------
#---------------------------------------------
#---------------------------------------------

synopsis = []

for syn in range(len(movie_links)):
    url = movie_links[syn]
    r = requests.get(url)
    soup = BeautifulSoup(r.content, "html")
    soup = soup.find("body")



    for section in soup.find_all("section", attrs={"id": "synopsis-details"}):
        for div in section.find_all("div", attrs={"class":"content-txt"}):
            synopsis.append(div.text)
            # need to remove \n before each synopsis
            print(div.text)



# Here are the things you will have to do for all links:
# - Slow down the frequency of requests to avoid being identified and therefore banned from the website.
# Use `time.sleep(random.uniform(1.0, 2.0))`
# - Get request object from URL
# - Extract the content into a variable using BeautifulSoup
# - Get title
# - Get synopsis

# Check the length of the lists before creating the dataframe
len(titles), len(synopsis), len(movie_links)
# Out:
# The Amateur
# Zion
# Piégé
# Mikado
# Bergers
# Le Village aux portes du paradis
# Her Story
# La Jeune femme à l’aiguille
# Jack
# Moon Le Panda
# Ma Mère, Dieu et Sylvie Vartan
# Blanche Neige
# Minecraft, Le Film
# Les Bodin’s partent en vrille
#
# Charlie Heller, un cryptographe de la CIA aussi brillant qu’introverti, voit son existence basculer lorsque sa femme décède durant une attaque terroriste perpétrée à Londres. Déplorant l’inaction de sa hiérarchie, il prend alors l’affaire en mains et se met à la recherche des assassins, embarquant pour un dangereux voyage partout à travers le monde pour assouvir sa vengeance.
#
#
# En Guadeloupe, Chris partage son temps entre deals, aventures sans lendemain et rodéos en moto. Repéré par Odell, le caïd du quartier voisin, Chris se voit confier une livraison à risque. Malgré la mise en garde de son meilleur ami, il accepte la mission. Mais le jour de la livraison, il découvre qu'un bébé a été déposé devant sa porte. Commence alors pour lui, une course infernale qui le mènera à un choix crucial...
#
#
# Un voleur s'introduit dans une voiture de luxe et se retrouve piégé à l'intérieur. Il découvre que son énigmatique propriétaire en a le contrôle total et qu’il va exercer sur lui une vengeance diabolique.
#
#
# Mikado et Laetitia vivent avec leurs enfants sur les routes. Une panne de moteur les amène à s’installer le temps d’un été chez Vincent, un enseignant qui vit seul avec sa fille. C’est le début d’une parenthèse enchantée qui pourrait aussi bouleverser l’équilibre de toute la famille alors que Nuage, leur fille aînée, se prend à rêver d’une vie normale.
#
#
# Sur un coup de tête, Mathyas troque sa vie de publicitaire à Montréal pour celle de berger en Provence. Il espérait trouver la quiétude, il découvre un métier éreintant et des éleveurs souvent à bout. Mais quand il rencontre Elise qui elle aussi vient de tout quitter, ils se voient confier un troupeau de 800 moutons et s’engagent dans une transhumance. Ensemble, ils vont traverser les épreuves de la montagne et se façonner une vie nouvelle.
#
#
# Un petit village du désert somalien, torride et venteux. Mamargade, père célibataire, cumule les petits boulots pour offrir à son fils Cigaal une vie meilleure. Alors qu’elle vient de divorcer, sa sœur Araweelo revient vivre avec eux. Malgré les vents changeants d’un pays en proie à la guerre civile et aux catastrophes naturelles, l’amour, la confiance et la résilience leur permettront de prendre en main leur destinée.
#
#
# Wang Tiemei, mère célibataire, s’installe avec sa jeune fille, Molly, dans l’espoir de repartir à zéro. Dans son nouveau quartier, elle noue une relation inattendue avec Xiao Ye, une romantique invétérée au regard du monde diamétralement opposé au sien. Malgré leurs différences, les deux femmes trouvent réconfort et force dans leur amitié, s’aidant mutuellement à guérir les blessures du passé et à affronter les défis du présent. Au fil de leur cheminement vers la découverte de soi et l'émancipation, deux hommes —tous deux sensibles aux questions de genre —viennent ajouter de la profondeur et de la complexité à la vie de Tiemei. Ces relations incitent chaque personnage à interroger leur compréhension du genre, à redéfinir leur rôle dans la société et à explorer ce que signifie vraiment se connecter aux autres.
#
#
# Copenhague, 1918. Karoline, une jeune ouvrière, lutte pour survivre Alors qu’elle tombe enceinte, elle rencontre Dagmar, une femme charismatique qui dirige une agence d'adoption clandestine. Un lien fort se crée entre les deux femmes et Karoline accepte un rôle de nourrice à ses côtés.
#
#
# Jack, un agent de renseignements atypique, se retrouve entraîné dans une conspiration internationale. Aux côtés de sa partenaire intrépide, il déjoue des plans machiavéliques mêlant action et humour. Ce thriller d'espionnage décalé offre une aventure rythmée pleine de rebondissements inattendus.
#
#
# Tian a 12 ans quand il est envoyé chez sa grand-mère à cause de ses mauvais résultats à l'école. Loin de la ville, dans les mystérieuses montagnes chinoises, il se lie d’amitié en secret avec un panda qu’il nomme Moon. C’est le début d’une incroyable aventure qui va changer à tout jamais sa vie et celle de sa famille.
#
#
# En 1963, Esther met au monde Roland, petit dernier d’une famille nombreuse. Roland naît avec un pied-bot qui l’empêche de se tenir debout. Contre l’avis de tous, elle promet à son fils qu’il marchera comme les autres et qu’il aura une vie fabuleuse. Dès lors, Esther n’aura de cesse de tout mettre en œuvre pour tenir cette promesse. À travers des décennies d’épreuves et de miracles de la vie, ce film est le récit d’une histoire vraie, drôle et bouleversante, celle d’un destin incroyable et du plus grand amour qui soit : celui d’une mère pour son enfant.
#
#
# "Blanche-Neige" des studios Disney est une nouvelle version du classique de 1937 en prises de vues réelles. Avec Rachel Zegler dans le rôle principal et Gal Gadot dans celui de sa belle-mère, la Méchante Reine. Cette aventure magique retourne aux sources du conte intemporel avec les adorables Timide, Prof, Simplet, Grincheux, Joyeux, Dormeur et Atchoum.
#
#
# Bienvenue dans l’univers de Minecraft où la créativité est essentielle à la survie ! Quatre outsiders – Garrett, Henry, Natalie et Dawn  – sont soudainement projetés à travers un mystérieux portail menant à La Surface – un incroyable monde cubique qui prospère grâce à l’imagination. Pour rentrer chez eux, il leur faudra maîtriser ce monde (et le protéger de créatures maléfiques comme les Piglins et les Zombies), tout en s’engageant dans une quête fantastique aux côtés de Steve, expert fabricateur. Cette aventure les poussera à être audacieux et à développer leur créativité. Autant de facultés dont ils auront besoin pour s’épanouir dans le monde réel.
#
#
# Quand Maria Bodin, fermière autoritaire et revêche, et son fils Christian, apprennent qu’une usine de fromage industrielle s’apprête à s’installer dans leur petit village, ils sont prêts à tout pour défendre leur fromagerie artisanale. Du Salon de l’agriculture au désert marocain, ils ne reculeront devant rien pour faire capoter ce projet d’usine : chantage, baston, courses-poursuites, une fois de plus, les Bodin’s vont braver tous les dangers pour sauver leurs valeurs et leurs traditions.
# (14, 14, 14)

# %%
import pandas as pd

df = pd.DataFrame({"Title": title})
df["Synopsis"] = synopsis
df["Links"] = movie_links

# %%
df.to_csv("./assets/allo_cine.csv", index=False)
